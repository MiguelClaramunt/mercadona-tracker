# %%
from mercatracker import globals, etl
import sqlite3
import pandas as pd

config = globals.load_dotenv(
    dotenv_shared="shared.env",
)

# parameters_list = [{'table': 'products', 'columns_to_select': '_PRODUCTS_COLUMNS', 'columns_to_hash': "PRODUCTS", 'subset_duplicates': ['id', 'hash']}, {'table': 'ids_categories', 'columns_to_select': '_IDS_CATEGORIES_COLUMNS', 'columns_to_hash': "CATEGORIES", 'subset_duplicates': ['id', 'hash']}, {'table': 'categories', 'columns_to_select': '_CATEGORIES_COLUMNS', 'columns_to_hash': "CATEGORIES_FINAL", 'subset_duplicates': ['hash']}]

# %%
import os
from mercatracker import io
from mercatracker.config import Config
import pandas as pd

config = Config().load()

# file = io.File(config[["ROOT_PATH", "ITEMS_FOLDER", 'LASTMOD']], ".csv")

# all_ids = set(config['ALL_IDS']) 

# checked = file.read(dtypes={"id": str})
config.lastmod
# Out:
# 20240608

# %%
config.dict_
# Out:
# {'LASTMOD_DATE': 20240608,
#  'ALL_IDS': ['35677',
#   '61250',
#   '34102',
#   '14423',
#   '37276',
#   '22823',
#   '46025',
#   '63592',
#   '44341',
#   '58261',
#   '60345',
#   '27905',
#   '28069',
#   '34184',
#   '28908',
#   '23372',
#   '22694',
#   '35344',
#   '15260',
#   '35887',
#   '19808',
#   '35643',
#   '7882',
#   '49976',
#   '80784',
#   '4041',
#   '46434',
#   '26011',
#   '67814',
#   '23047',
#   '16737',
#   '80398',
#   '15794',
#   '17327',
#   '35402',
#   '22453',
#   '59336',
#   '52891',
#   '49750',
#   '52884',
#   '23048',
#   '67660',
#   '13576',
#   '27414',
#   '49154',
#   '72537',
#   '63629',
#   '44000',
#   '79260',
#   '79344',
#   '20584',
#   '15967',
#   '54209',
#   '5005',
#   '83558',
#   '16833',
#   '80515',
#   '50614',
#   '23926',
#   '71527',
#   '28506',
#   '15597',
#   '69099',
#   '5219',
#   '69519',
#   '15936',
#   '28190',
#   '5042',
#   '28187',
#   '35541',
#   '79632',
#   '23646',
#   '20029',
#   '86835',
#   '62503',
#   '63597',
#   '22697',
#   '28311',
#   '52426',
#   '52686',
#   '20991',
#   '23353',
#   '10354',
#   '52488',
#   '73988',
#   '11427',
#   '26174',
#   '67712',
#   '16830',
#   '78516',
#   '46862',
#   '60846',
#   '38145',
#   '86593',
#   '53041',
#   '39922',
#   '44982',
#   '22002',
#   '26039',
#   '11732',
#   '82732',
#   '23544',
#   '73252',
#   '8295',
#   '80353',
#   '22009',
#   '65324',
#   '82655',
#   '46771',
#   '3236',
#   '10678',
#   '22926',
#   '80267',
#   '40275',
#   '60128',
#   '60127',
#   '46766',
#   '67635',
#   '43088',
#   '44984',
#   '15985',
#   '53500',
#   '21151',
#   '50916',
#   '34817',
#   '43028',
#   '73002',
#   '3460',
#   '12362',
#   '35633',
#   '21307',
#   '23037',
#   '22688',
#   '51230',
#   '82417',
#   '73195',
#   '4797',
#   '4798',
#   '20107',
#   '73172',
#   '35881',
#   '47600',
#   '23413',
#   '46405',
#   '59993',
#   '63477',
#   '9395',
#   '67967',
#   '76465',
#   '55017',
#   '22007',
#   '58488',
#   '79358',
#   '9281',
#   '15664',
#   '52533',
#   '86469',
#   '14080',
#   '4912',
#   '63474',
#   '73274',
#   '69246',
#   '82610.3',
#   '3506',
#   '82610.4',
#   '81234.4',
#   '60440',
#   '23702',
#   '22836',
#   '43474',
#   '81416',
#   '52877',
#   '15137',
#   '35420',
#   '40277',
#   '10226',
#   '58154',
#   '60719',
#   '8122',
#   '35475',
#   '15628',
#   '76178',
#   '73443',
#   '58286',
#   '52607',
#   '12017',
#   '5396',
#   '86588',
#   '18055',
#   '11307',
#   '84937',
#   '86905',
#   '22631',
#   '28494',
#   '6282',
#   '40259',
#   '63478',
#   '87616',
#   '87683',
#   '62499',
#   '78132',
#   '15922',
#   '82117',
#   '78510',
#   '85786',
#   '54105',
#   '87607',
#   '34121',
#   '69469',
#   '52503',
#   '23410',
#   '34125',
#   '14131',
#   '44924',
#   '35983',
#   '44262',
#   '78975',
#   '67940',
#   '42384',
#   '9377',
#   '52973',
#   '22281',
#   '40573',
#   '17163',
#   '34138',
#   '2851',
#   '17108',
#   '23662',
#   '46877',
#   '11470',
#   '24016',
#   '3499',
#   '52560',
#   '35274',
#   '24511',
#   '64087',
#   '50654',
#   '60348',
#   '67949',
#   '23516',
#   '2856',
#   '23019',
#   '63526',
#   '35804',
#   '67125',
#   '35545',
#   '35360',
#   '25353',
#   '46834',
#   '23013',
#   '79080',
#   '77241',
#   '82585',
#   '52481',
#   '23523',
#   '71227',
#   '67534',
#   '44508',
#   '44363',
#   '16004',
#   '23540',
#   '76596',
#   '47608',
#   '67658',
#   '27571',
#   '63628',
#   '46420',
#   '79531',
#   '23643',
#   '18313',
#   '7949',
#   '52553',
#   '35934',
#   '3297',
#   '14159',
#   '33581',
#   '22180',
#   '60790',
#   '50124',
#   '88407',
#   '59343',
#   '44280',
#   '35590',
#   '55130',
#   '27487',
#   '73445',
#   '55028',
#   '6245',
#   '37164',
#   '13631',
#   '52850',
#   '46615',
#   '50170',
#   '52852',
#   '63532',
#   '24032',
#   '51068',
#   '32045',
#   '59254',
#   '63451',
#   '24708',
#   '40583',
#   '13598',
#   '52738',
#   '61248',
#   '11172',
#   '82302',
#   '60581',
#   '33436',
#   '22280',
#   '13615',
#   '11770',
#   '4915',
#   '61027',
#   '8187',
#   '50375',
#   '27491',
#   '7031',
#   '46953',
#   '29608',
#   '86231',
#   '47818',
#   '69166',
#   '83869',
#   '23052',
#   '82938',
#   '50326',
#   '22081',
#   '44289',
#   '63606',
#   '43223',
#   '52669',
#   '47349',
#   '60623',
#   '63528',
#   '35540',
#   '35531',
#   '52531',
#   '21358',
#   '87609',
#   '55142',
#   '43482',
#   '79712',
#   '19740',
#   '53032',
#   '46857',
#   '51079',
#   '80782',
#   '15777',
#   '39934',
#   '68125',
#   '44286',
#   '13388',
#   '7881',
#   '66026',
#   '79069',
#   '29019',
#   '38007',
#   '51193',
#   '80707',
#   '14639',
#   '86040',
#   '3561',
#   '46893',
#   '49302',
#   '86288',
#   '15076',
#   '15810',
#   '27971',
#   '50459',
#   '69414',
#   '35944',
#   '33120',
#   '51167',
#   '61034',
#   '22343',
#   '86021',
#   '82277',
#   '42296',
#   '60015',
#   '22503',
#   '50256',
#   '52532',
#   '16807',
#   '46768',
#   '50192',
#   '50199',
#   '35723',
#   '39404',
#   '15705',
#   '65139',
#   '50984',
#   '22249',
#   '9264',
#   '34963',
#   '51239',
#   '29072',
#   '15757',
#   '62131',
#   '35679',
#   '49869',
#   '27735',
#   '50140',
#   '50633',
#   '22721',
#   '24256',
#   '50972',
#   '66518',
#   '22459',
#   '23568',
#   '67899',
#   '50198',
#   '35841',
#   '23630',
#   '29314',
#   '73272',
#   '52932',
#   '50125',
#   '9040',
#   '46885',
#   '61363',
#   '46948',
#   '46087',
#   '15648',
#   '35342',
#   '50366',
#   '29410',
#   '27488',
#   '86087',
#   '28662',
#   '86659',
#   '3453',
#   '79713',
#   '20037',
#   '49333',
#   '7035',
#   '8727',
#   '83789',
#   '61288',
#   '52645',
#   '16415',
#   '83858.1',
#   '51012',
#   '61053',
#   '61305',
#   '29036',
#   '60347',
#   '86233',
#   '42204',
#   '70370',
#   '23172',
#   '68149',
#   '22621',
#   '49049',
#   '4888',
#   '10670',
#   '20830',
#   '86610.1',
#   '68106',
#   '86610.2',
#   '11077',
#   '67906',
#   '61368',
#   '35668',
#   '49975',
#   '44914',
#   '35774',
#   '66107',
#   '13652',
#   '7980',
#   '51627',
#   '46989',
#   '39403',
#   '58248',
#   '78073',
#   '51641',
#   '23701',
#   '72614',
#   '52590',
#   '4425',
#   '35661',
#   '84643',
#   '8290',
#   '35579',
#   '60659',
#   '46390',
#   '60667',
#   '60688',
#   '60946',
#   '46441',
#   '23675',
#   '60551',
#   '66172',
#   '18037',
#   '29373',
#   '50480',
#   '27610',
#   '80253',
#   '11171',
#   '35749',
#   '35378',
#   '20031',
#   '84654',
#   '8267',
#   '39902',
#   '52934',
#   '51110',
#   '35101',
#   '51149',
#   '86803',
#   '27761',
#   '43315',
#   '69976',
#   '3454',
#   '79678',
#   '40315',
#   '11319',
#   '73984',
#   '86341',
#   '23798',
#   '65327',
#   '52977',
#   '86886',
#   '79594',
#   '35961',
#   '79707',
#   '14085',
#   '71044',
#   '80531',
#   '43853',
#   '43914',
#   '76542',
#   '52467',
#   '26110',
#   '27230',
#   '82651',
#   '35969',
#   '62012',
#   '70024',
#   '23231',
#   '34865',
#   '3547',
#   '35593',
#   '4900',
#   '69757',
#   '3554',
#   '63114',
#   '50478',
#   '47609',
#   '61302',
#   '69810',
#   '7956',
#   '17131',
#   '13814',
#   '3433',
#   '35714',
#   '22623',
#   '51199',
#   '2873',
#   '34217',
#   '9571',
#   '2849',
#   '34811',
#   '35733',
#   '23059',
#   '62048',
#   '76637',
#   '15220',
#   '47030',
#   '22799',
#   '30138',
#   '22133',
#   '86597',
#   '67981',
#   '86238',
#   '52794',
#   '10543',
#   '31312',
#   '70646',
#   '16313',
#   '87731',
#   '52936',
#   '35662',
#   '14645',
#   '44281',
#   '8838',
#   '22131',
#   '50985',
#   '35534',
#   '58489',
#   '13431',
#   '86547',
#   '44355',
#   '10380',
#   '23449',
#   '17039',
#   '58278',
#   '69876',
#   '52562',
#   '60653',
#   '51197',
#   '10546',
#   '4908',
#   '35732',
#   '13430',
#   '28296',
#   '69657',
#   '2439',
#   '28288',
#   '49711',
#   '60384',
#   '50321',
#   '52108',
#   '35641',
#   '23117',
#   '34163',
#   '11187',
#   '46550',
#   '11719',
#   '23406',
#   '10532',
#   '16831',
#   '10516',
#   '35941',
#   '9581',
#   '29004',
#   '64249',
#   '46659',
#   '11872',
#   '90080',
#   '52573',
#   '52183',
#   '23670',
#   '64012',
#   '82070',
#   '23291',
#   '64248',
#   '3651',
#   '87194',
#   '67144',
#   '76937',
#   '31540',
#   '23404',
#   '2779',
#   '46724',
#   '51194',
#   '60251',
#   '82099',
#   '28757',
#   '35654',
#   '52853',
#   '39109',
#   '64518',
#   '87734',
#   '82842',
#   '22279',
#   '13848',
#   '64419',
#   '43320',
#   '23373',
#   '63581',
#   '35602',
#   '68089',
#   '60046',
#   '9356',
#   '66896',
#   '6152',
#   '16317',
#   '39127',
#   '10355',
#   '69881',
#   '52837',
#   '8856',
#   '37229',
#   '80497',
#   '49704',
#   '20476',
#   '69585',
#   '20200',
#   '22780',
#   '22191',
#   '42318',
#   '52892',
#   '20940',
#   '22580',
#   '46418',
#   '64435',
#   '73270',
#   '33440',
#   '59230',
#   '17502',
#   '22612',
#   '84900',
#   '67060',
#   '22008',
#   '86033',
#   '27598',
#   '23596',
#   '46865',
#   '10801',
#   '2155',
#   '52538',
#   '80980',
#   '64523',
#   '35627',
#   '46020',
#   '64436',
#   '13713',
#   '80862',
#   '74044',
#   '34193',
#   '39129',
#   '24417',
#   '76504',
#   '46730',
#   '35392',
#   '47310',
#   '21336',
#   '27426',
#   '4570',
#   '61354',
#   '27136',
#   '52821',
#   '17132',
#   '59130',
#   '51151',
#   '35777',
#   '15968',
#   '2860',
#   '45913',
#   '86505',
#   '22837',
#   '20859',
#   '20942',
#   '63140',
#   '6250',
#   '23337',
#   '16757',
#   '52992',
#   '80858',
#   '38131',
#   '60631',
#   '12098',
#   '84688',
#   '33357',
#   '44116',
#   '35397',
#   '26101',
#   '50971',
#   '10505',
#   '33108',
#   '86276',
#   '35362',
#   '13643',
#   '13849',
#   '82032',
#   '46424',
#   '35822',
#   '7880',
#   '50546',
#   '43923',
#   '9445',
#   '52996',
#   '52527',
#   '5398',
#   '10826',
#   '60587',
#   '34173',
#   '46871',
#   '12509',
#   '4493',
#   '82322',
#   '26114',
#   '12126',
#   '34924',
#   '65311',
#   '23051',
#   '72408',
#   '21333',
#   '82735',
#   '14216',
#   '52559',
#   '35851',
#   '23066',
#   '52740',
#   '8394',
#   '10814',
#   '5593',
#   '60718',
#   '15862',
#   '12099',
#   '19859',
#   '27842',
#   '71399',
#   '14210',
#   '23277',
#   '8548',
#   '35849',
#   '82905',
#   '23405',
#   '22718',
#   '52561',
#   '21329',
#   '51223',
#   '13422',
#   '8305',
#   '48652',
#   '63643',
#   '78031',
#   '27054',
#   '59332',
#   '5522',
#   '43057',
#   '46444',
#   '20571',
#   '20727',
#   '9491',
#   '7944',
#   '73269',
#   '13548',
#   '16717',
#   '28566',
#   '17173',
#   '55125',
#   '69889',
#   '65328',
#   '26001',
#   '7943',
#   '74079',
#   '49224',
#   '35639',
#   '23049',
#   '23574',
#   '86100',
#   '22651',
#   '4868',
#   '35403',
#   '65298',
#   '80151',
#   '40365',
#   '13636',
#   '34035',
#   '29322',
#   '79433',
#   '4918',
#   '52782',
#   '34997',
#   '52795',
#   '22899',
#   '22967',
#   '63476',
#   '9210',
#   '23365',
#   '35880',
#   '4040',
#   '34721',
#   '40246',
#   '14161',
#   '84582',
#   '23476',
#   '64200',
#   '65299',
#   '84940',
#   '39191',
#   '34262',
#   '52588',
#   '9407',
#   '34188',
#   '18252',
#   '34921',
#   '73331',
#   '21331',
#   '22078',
#   '60530',
#   '35770',
#   '27449',
#   '43820',
#   '21319',
#   '23477',
#   '9357',
#   '65077',
#   '35266',
#   '35594',
#   '20941',
#   '70745',
#   '64445',
#   '72548',
#   '4361',
#   '27972',
#   '28102',
#   '8280',
#   '63407',
#   '22302',
#   '80361',
#   '78983',
#   '44019',
#   '64196',
#   '35345',
#   '79035',
#   '33026',
#   '43931',
#   '23560',
#   '39900',
#   '23890',
#   '60945',
#   '33639',
#   '34868',
#   '19837',
#   '73979',
#   '10882',
#   '13445',
#   '52937',
#   '63159',
#   '4957',
#   '5000',
#   '73166',
#   '44283',
#   '69155',
#   '50994',
#   '20196',
#   '10050',
#   '45711',
#   '3553',
#   '10054',
#   '73196',
#   '10051',
#   '15942',
#   '14010',
#   '60307',
#   '9421',
#   '59138',
#   '84482',
#   '84629',
#   '9188',
#   '29074',
#   '13417',
#   '9508',
#   '46658',
#   '75306',
#   '35896',
#   '14087',
#   '43058',
#   '66771',
#   '61215',
#   '8194',
#   '29031',
#   '22648',
#   '46567',
#   '64464',
#   '85827',
#   '7014',
#   '23359',
#   '23513',
#   '61282',
#   '23561',
#   '23908',
#   '67774',
#   '46436',
#   '35831',
#   '60354',
#   '15923',
#   '29540',
#   '10117',
#   '47554',
#   '67797',
#   '60576',
#   '72544',
#   '73268',
#   '30006',
#   '15966',
#   '82931',
#   '46995',
#   '52796',
#   '82098',
#   '60954',
#   '14637',
#   '27234',
#   '64166',
#   '43484',
#   '23003',
#   '11101',
#   '5546',
#   '35785',
#   '7026',
#   '67753',
#   '63509',
#   '73989',
#   '34149',
#   '16005',
#   '21199',
#   '16040',
#   '63582',
#   '17346',
#   '22723',
#   '38130',
#   '82609',
#   '62396',
#   '81661.1',
#   '14113',
#   '15953',
#   ...],
#  'TURSO_AUTH_TOKEN': 'eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3MTQzOTcxNDMsImlkIjoiM2MxZDExZjgtNTE5Yi00Mzg2LWE0ZTMtOTQ4ODBlYWM2YWI4In0.TV1cANsRrUwnV1Wi_sg6dUIq7PZ6kn7a2kKGMmcYI9u0SPM3Tz0G3PdQnGGAgqv6n_4SsEBDb1IWbJec3SCbBA',
#  'ROOT_PATH': '/home/miguel/git/mercadona-tracker',
#  'ITEMS_FOLDER': 'items',
#  'URL_SITEMAP': 'https://tienda.mercadona.es/sitemap.xml',
#  'URL_API': 'https://tienda.mercadona.es/api/v1_1/products',
#  'URL_CATEGORIES': 'https://tienda.mercadona.es/api/categories',
#  'URL_IMAGES': 'https://prod-mercadona.imgix.net/images',
#  'PARAMS_API': {'lang': 'es', 'wh': 'vlc1'},
#  'PARAMS_THUMBNAIL': {'fit': 'crop', 'h': 300, 'w': 300},
#  'FORMAT_DATE': '%Y%m%d',
#  'TURSO_DATABASE_URL': 'libsql://mercadona-tracker-miguelclaramunt.turso.io',
#  'YMD': ['ymd'],
#  'IDS': ['id', 'ean'],
#  'HASH': ['hash'],
#  'CATEGORIES_JSON': ['categories'],
#  'PRICES': ['iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount'],
#  'PRODUCTS': ['slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients'],
#  'CATEGORIES': ['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name'],
#  'CATEGORIES_FINAL': ['level', 'name'],
#  '_CATEGORIES_JER': [['l1', 'l1_name', 'ymd'],
#   ['l2', 'l2_name', 'ymd'],
#   ['l3', 'l3_name', 'ymd']],
#  'COLS_TO_DROP': ['suppliers',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'allergens'],
#  'ITEMS_DTYPES': {'id': 'string',
#   'ean': 'int',
#   'slug': 'string',
#   'brand': 'string',
#   'is_water': 'bool',
#   'requires_age_check': 'bool',
#   'origin': 'string',
#   'brand_1': 'string',
#   'origin_1': 'string',
#   'suppliers': 'string',
#   'legal_name': 'string',
#   'description': 'string',
#   'counter_info': 'string',
#   'danger_mentions': 'string',
#   'alcohol_by_volume': 'string',
#   'mandatory_mentions': 'string',
#   'production_variant': 'string',
#   'usage_instructions': 'string',
#   'storage_instructions': 'string',
#   'is_bulk': 'bool',
#   'packaging': 'string',
#   'published': 'bool',
#   'thumbnail': 'string',
#   'display_name': 'string',
#   'is_variable_weight': 'bool',
#   'iva': 'int',
#   'is_new': 'bool',
#   'is_pack': 'bool',
#   'pack_size': 'float64',
#   'unit_name': 'category',
#   'unit_size': 'float',
#   'bulk_price': 'float',
#   'unit_price': 'float',
#   'approx_size': 'bool',
#   'size_format': 'category',
#   'total_units': 'int',
#   'unit_selector': 'bool',
#   'bunch_selector': 'bool',
#   'drained_weight': 'float64',
#   'selling_method': 'int',
#   'price_decreased': 'bool',
#   'reference_price': 'float',
#   'min_bunch_amount': 'float64',
#   'reference_format': 'string',
#   'previous_unit_price': 'string',
#   'increment_bunch_amount': 'float64',
#   'allergens': 'string',
#   'ingredients': 'string',
#   'l1': 'int',
#   'l1_name': 'string',
#   'l2': 'int',
#   'l2_name': 'string',
#   'l3': 'int',
#   'l3_name': 'string',
#   'ymd': 'string'},
#  'COLS_WITH_ALIASES': ['_ITEMS_COLS',
#   'ITEMS_COLS',
#   '_PRICES_COLS',
#   'PRICES_COLS',
#   '_PRODUCTS_COLS',
#   'PRODUCTS_COLS',
#   '_CATEGORIES_COLS',
#   'CATEGORIES_COLS',
#   '_IDS_CATEGORIES_COLS',
#   'IDS_CATEGORIES_COLS'],
#  '_ITEMS_COLS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'categories',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'ymd'],
#  'ITEMS_COLS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'ymd'],
#  '_PRICES_COLS': ['id',
#   'ean',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'ymd'],
#  'PRICES_COLS': ['id',
#   'ean',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'hash',
#   'ymd'],
#  '_PRODUCTS_COLS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'ymd'],
#  'PRODUCTS_COLS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'hash',
#   'ymd'],
#  '_CATEGORIES_COLS': ['level', 'name', 'ymd'],
#  'CATEGORIES_COLS': ['level', 'name', 'hash', 'ymd'],
#  '_IDS_CATEGORIES_COLS': ['id',
#   'ean',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'ymd'],
#  'IDS_CATEGORIES_COLS': ['id',
#   'ean',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'hash',
#   'ymd'],
#  'ETL_PARAMETERS': [{'table': 'products',
#    'cols_to_select': ['id',
#     'ean',
#     'slug',
#     'brand',
#     'is_water',
#     'requires_age_check',
#     'origin',
#     'brand1',
#     'origin1',
#     'suppliers',
#     'legal_name',
#     'description',
#     'counter_info',
#     'danger_mentions',
#     'alcohol_by_volume',
#     'mandatory_mentions',
#     'production_variant',
#     'usage_instructions',
#     'storage_instructions',
#     'is_bulk',
#     'packaging',
#     'published',
#     'thumbnail',
#     'display_name',
#     'is_variable_weight',
#     'allergens',
#     'ingredients',
#     'ymd'],
#    'cols_to_hash': ['slug',
#     'brand',
#     'is_water',
#     'requires_age_check',
#     'origin',
#     'brand1',
#     'origin1',
#     'suppliers',
#     'legal_name',
#     'description',
#     'counter_info',
#     'danger_mentions',
#     'alcohol_by_volume',
#     'mandatory_mentions',
#     'production_variant',
#     'usage_instructions',
#     'storage_instructions',
#     'is_bulk',
#     'packaging',
#     'published',
#     'thumbnail',
#     'display_name',
#     'is_variable_weight',
#     'allergens',
#     'ingredients'],
#    'subset_duplicates': ['id', 'hash']},
#   {'table': 'ids_categories',
#    'cols_to_select': ['id',
#     'ean',
#     'l1',
#     'l1_name',
#     'l2',
#     'l2_name',
#     'l3',
#     'l3_name',
#     'ymd'],
#    'cols_to_hash': ['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name'],
#    'subset_duplicates': ['id', 'hash']},
#   {'table': 'categories',
#    'cols_to_select': ['level', 'name', 'ymd'],
#    'cols_to_hash': ['level', 'name'],
#    'subset_duplicates': ['hash']}]}

# %%
type(checked)
# Out:
# set

# %%
print(len(all_ids), len(checked))
print(len(all_ids - checked))
# Out:
# 4812 2759
# 2053

# %%
print(len(all_ids), len(checked))
# Out:
# 4812 0

# %%
from pathlib import Path
import os
from mercatracker.path import build, get_project_dir

Config.load()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 str(build((os.path.abspath(""), "*"), ".env"))
#       6 # str(build((get_project_dir(), "src", "*"), ".env"))
# ----> 8 Config._search(build((get_project_dir(), "src", "*"), ".env"))
#
# NameError: name 'Config' is not defined

# %%
from mercatracker import path

path.build((path.get_project_dir(), "src", "*"), ".env")
# Out:
# PosixPath('/home/miguel/git/mercadona-tracker/src/*.env')

# %%
import os
os.path.abspath(os.curdir)
# Out:
# '/home/miguel/git/mercadona-tracker/src'

# %%
from pathlib import Path

import dotenv
import os
from mercatracker import io
from mercatracker.config import Config
import pandas as pd

config = Config().load()
config.paths['shared']
Path(os.path.abspath(""))
os.path.abspath(os.path.join(os.path.dirname(Path(os.path.abspath(""))), '..', '.env')) #travels up a level to find the .env

# config.update(file='/home/miguel/git/mercadona-tracker/temp.env', var={"aa": 'aa'})
# /home/miguel/git/mercadona-tracker/temp.env
# file = 'shared'
# project_dir = str(
#     [
#         p
#         for p in Path(os.path.abspath("")).parents
#         if p.parts[-1] == "mercadona-tracker"
#     ][0]
# )
# if config["ROOT_PATH"] != project_dir:
#     print(config["ROOT_PATH"])
#     for k, v in {"ROOT_PATH": project_dir}.items():
#         dotenv.set_key(
#             dotenv_path=config.paths[file],
#             key_to_set=k,
#             value_to_set=v,
#         )

# print(config["ROOT_PATH"])
# Out:
# '/home/miguel/git/.env'

# %%
import glob
from mercatracker import path

glob.glob(f"{path.get_project_dir()}/*.env")
# Out:
# ['/home/miguel/git/mercadona-tracker/temp.env',
#  '/home/miguel/git/mercadona-tracker/secret.env',
#  '/home/miguel/git/mercadona-tracker/shared.env']

# %%
# config["ROOT_PATH"]
path.build(f"{config['ROOT_PATH']}/*.env")
# Out:
# '/home/miguel/git/mercadona-tracker/*.env'

# %%
from mercatracker import path


path.build((config['ROOT_PATH'], "*"), ".env")
# Out:
# PosixPath('/home/miguel/git/mercadona-tracker/*.env')

# %%
os.path.isfile(io.File(config[["ROOT_PATH", "ITEMS_FOLDER", 'LASTMOD']], ".csv").path)

# %%
pd.DataFrame(columns=config["ITEMS_COLS"]).to_csv(header=True, index=False, columns=config["ITEMS_COLS"])
# Out:
# 'id,ean,slug,brand,is_water,requires_age_check,origin,brand1,origin1,suppliers,legal_name,description,counter_info,danger_mentions,alcohol_by_volume,mandatory_mentions,production_variant,usage_instructions,storage_instructions,is_bulk,packaging,published,thumbnail,display_name,is_variable_weight,allergens,ingredients,iva,is_new,is_pack,pack_size,unit_name,unit_size,bulk_price,unit_price,approx_size,size_format,total_units,unit_selector,bunch_selector,drained_weight,selling_method,price_decreased,reference_price,min_bunch_amount,reference_format,previous_unit_price,increment_bunch_amount,l1,l1_name,l2,l2_name,l3,l3_name,ymd\n'

# %%
file.write_header(pd.DataFrame(columns=config["ITEMS_COLS"]).to_csv(header=True, index=False, columns=config["ITEMS_COLS"]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 file.write_header(pd.DataFrame(columns=config["ITEMS_COLS"]).to_csv(header=True, index=False, columns=config["ITEMS_COLS"]))
#
# File ~/git/mercadona-tracker/src/mercatracker/io.py:55, in File.write_header(self, text, mode)
#      54 def write_header(self, text: str, mode: str = 'x'):
# ---> 55     with open(self.path, mode=mode) as f:
#      56         f.write(text)
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/git/mercadona-tracker/items/20240521.csv'

# %%
from operator import itemgetter

itemgetter("ROOT_PATH", "ITEMS_FOLDER")(config)
# Out:
# ('~/git/mercadona-tracker/', 'items')

# %%
from mercatracker import path, scraping
from mercatracker.config import Config
config = Config().load(postprocess=False)
path.build(config[["ROOT_PATH", "ITEMS_FOLDER", 'LASTMOD']], ".csv")
# Out:
# PosixPath('~/git/mercadona-tracker/items/20240521.csv')

# %%
from mercatracker import path, scraping
from mercatracker.config import Config
from operator import itemgetter
import pandas as pd

config = Config().load(postprocess=False)
# itemgetter("ROOT_PATH", "ITEMS_FOLDER")(config.dict_)
# config[["ROOT_PATH", "ITEMS_FOLDER"]]
# config[["ROOT_PATH", "ITEMS_FOLDER"]]
# all_ids = set(config["ALL_IDS"])
# filename = path.build(config["ITEMS_FOLDER"], 20240523, "csv")
# checked = set(scraping.get_current_ids(filename=filename))

# %%
*map(str, config[["ROOT_PATH", "ITEMS_FOLDER", 'LASTMOD']]),
# Out:
# ('~/git/mercadona-tracker/', 'items', '20240521')

# %%
import pathlib

levels = config[["ROOT_PATH", "ITEMS_FOLDER", 'LASTMOD']]
extension = '.csv'
levels = (*map(str, levels),)
pathlib.Path(*levels).with_suffix(extension)
# Out:
# PosixPath('~/git/mercadona-tracker/items/20240521.csv')

# %%
levels[-1]+'.csv'
# Out:
# '20240521.csv'

# %%
import os
extension = "csv"
os.path.join(*config[["ROOT_PATH", "ITEMS_FOLDER", 'LASTMOD']], f".{extension}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
#       2 extension = "csv"
# ----> 3 os.path.join(*config[["ROOT_PATH", "ITEMS_FOLDER", "LASTMOD_DATE"]], f".{extension}")
#
# File <frozen posixpath>:90, in join(a, *p)
#
# File <frozen genericpath>:164, in _check_arg_types(funcname, *args)
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'int'

# %%
from mercatracker.config import Config
from mercatracker.scraper import Soup

config = Config().load(postprocess=False)

soup = Soup(url=config["URL_SITEMAP"]).request()

# %%
# soup.get_lastmod()

config.update({"ALL_IDS": str(soup.get_ids())})

# %%
from pathlib import Path
import dotenv
from mercatracker.config import Config

# config = Config().load(postprocess=True)
# config['ETL_PARAMETERS'] = 'holaa'
# config['ETL_PARAMETERS']

Config().update()

# {Path(path).stem: path for path in Config().paths}.values()
# Out:
# Config(paths={'temp': '/home/miguel/git/mercadona-tracker/temp.env', 'secret': '/home/miguel/git/mercadona-tracker/secret.env', 'shared': '/home/miguel/git/mercadona-tracker/shared.env'}, os=None)

# %%
config['ETL_PARAMETERS']
# Out:
# [{'table': 'products',
#   'cols_to_select': '_PRODUCTS_COLS',
#   'cols_to_hash': 'PRODUCTS',
#   'subset_duplicates': ['id', 'hash']},
#  {'table': 'ids_categories',
#   'cols_to_select': '_IDS_CATEGORIES_COLS',
#   'cols_to_hash': 'CATEGORIES',
#   'subset_duplicates': ['id', 'hash']},
#  {'table': 'categories',
#   'cols_to_select': '_CATEGORIES_COLS',
#   'cols_to_hash': 'CATEGORIES_FINAL',
#   'subset_duplicates': ['hash']}]

# %%
for element in config['ETL_PARAMETERS']:
    print(Config._convert_aliases([element['cols_to_hash']]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 for element in config['ETL_PARAMETERS']:
# ----> 2     print(Config._convert_aliases([element['cols_to_hash']]))
#
# File ~/git/mercadona-tracker/src/mercatracker/config.py:70, in Config._convert_aliases(self, meta_var)
#      56 def _convert_aliases(self, meta_var: str = "COLS_WITH_ALIASES") -> "Config":
#      57     """Convert aliases into its values from a meta-variable.
#      58
#      59     From this aliases `YMD`, `CATEGORIES_FINAL`; and the meta-variable `COLS_WITH_ALIASES`:
#    (...)
#      68         meta_var (str, optional): Meta-variable, contains all variables to convert. Defaults to "COLS_WITH_ALIASES".
#      69     """
# ---> 70     for var in self.dict_[meta_var]:
#      71         self.dict_[var] = sum(
#      72             [self.dict_[column] for column in self.dict_[var]], []
#      73         )
#      75     return self
#
# AttributeError: 'list' object has no attribute 'dict_'

# %%
paths = ('../secret.env',)
dict(chain.from_iterable(dotenv.dotenv_values(dotenv_path=path).items() for path in paths))
# Out:
# {'TURSO_AUTH_TOKEN': 'eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3MTQzOTcxNDMsImlkIjoiM2MxZDExZjgtNTE5Yi00Mzg2LWE0ZTMtOTQ4ODBlYWM2YWI4In0.TV1cANsRrUwnV1Wi_sg6dUIq7PZ6kn7a2kKGMmcYI9u0SPM3Tz0G3PdQnGGAgqv6n_4SsEBDb1IWbJec3SCbBA'}

# %%
import glob
import os
from typing import List
# from mercatracker import config
from itertools import chain
import dotenv

def __search(path: str) -> list:
    return glob.glob(pathname=path)

def load_dotenv(paths: List[str,]) -> dict:
    return dict(
        chain.from_iterable(
            dotenv.dotenv_values(dotenv_path=path).items() for path in paths
        )
    )

# config.Config()
paths = __search(os.path.expanduser("~/git/mercadona-tracker/*.env"))
load_dotenv(paths)

# 
# def test_load_dotenv():
#     # config = Config(shared='.env.test')
#     assert (config.load_dotenv('.env.test')['TEST_STR'] == 'string')
# Out:
# {'LASTMOD_DATE': '20240521',
#  'ALL_IDS': "['63464', '35677', '61250', '34102', '14423', '37276', '22823', '46025', '63592', '44341', '58261', '60345', '27905', '34184', '23372', '22694', '35344', '15260', '35887', '19808', '35643', '7882', '49976', '80784', '4041', '12364', '46434', '26011', '67814', '23047', '16737', '80398', '15794', '17327', '35402', '22453', '46954', '52561', '59336', '52891', '49750', '52884', '23048', '67660', '13576', '27414', '49154', '72537', '63629', '44000', '79260', '79344', '20584', '15967', '4493', '54209', '5005', '83558', '16833', '80515', '50614', '23926', '71527', '28506', '15597', '69099', '5219', '69519', '15936', '28190', '5042', '28187', '35541', '79632', '23646', '20029', '86835', '62503', '63597', '22697', '52426', '52686', '3651', '20991', '67930', '23353', '10354', '73988', '28775', '11427', '26174', '67712', '16830', '78516', '46862', '60846', '38145', '86593', '53041', '63451', '39922', '44982', '26039', '11732', '82732', '23544', '73252', '8295', '80353', '22009', '65324', '82655', '46771', '3236', '10678', '22926', '80267', '40275', '60128', '60127', '46766', '67635', '43088', '87616', '44984', '15985', '53500', '21151', '50916', '34817', '43028', '73002', '3460', '82551', '35633', '69469', '21307', '23037', '22688', '82417', '73195', '4491', '4797', '4798', '20107', '73172', '86749', '35881', '47600', '23413', '46405', '59993', '82609', '63477', '9395', '67967', '76465', '13417', '22007', '58488', '79358', '52533', '86469', '14080', '4912', '63474', '73274', '23702', '22836', '43474', '52877', '15137', '35420', '40277', '10226', '58154', '60719', '8122', '35475', '15628', '76178', '73443', '58286', '52607', '12017', '5396', '86588', '18055', '11307', '84937', '86905', '22631', '28494', '6282', '40259', '63478', '87683', '70756', '62499', '78132', '15922', '82117', '78510', '85786', '34115', '54105', '87607', '34121', '52503', '23410', '34125', '14131', '35983', '44262', '14212', '78975', '28069', '67940', '42384', '9377', '52973', '22281', '40573', '34138', '2851', '17108', '23662', '46877', '11470', '29062', '49619', '24016', '3499', '52560', '35274', '24511', '64087', '50654', '60348', '67949', '23516', '2856', '23019', '63526', '67125', '35545', '35360', '25353', '46834', '23013', '79080', '77241', '82585', '52481', '3291', '23523', '71227', '67534', '44508', '44363', '34236', '16004', '23540', '76596', '47608', '67658', '27571', '63628', '46420', '22932', '40358', '79531', '23643', '18313', '7949', '52553', '35934', '3297', '14159', '33581', '22180', '60790', '50124', '88407', '59343', '44280', '35590', '55130', '73445', '55028', '6245', '37164', '13631', '52850', '46615', '50170', '52852', '63532', '84930', '24032', '51068', '32045', '59254', '24708', '40583', '13598', '52738', '64249', '61248', '11172', '23773', '82302', '60581', '33436', '22280', '13615', '52445', '11770', '60722', '4915', '61027', '8187', '50375', '27491', '7031', '9034', '46953', '86231', '47818', '69166', '83869', '23052', '82938', '50326', '22081', '44289', '63606', '43223', '52669', '47349', '59078', '60623', '70652', '63528', '35540', '35531', '52531', '21358', '87609', '55142', '43482', '79712', '19740', '53032', '46857', '51079', '80782', '15777', '44286', '13388', '7881', '79069', '29019', '38007', '51193', '80707', '14639', '86040', '3561', '46893', '49302', '86288', '15076', '27971', '50459', '35944', '33120', '51167', '50545', '61034', '52941', '22343', '86021', '82277', '86798', '42296', '60015', '22503', '50256', '12531', '52532', '16807', '46768', '50192', '50199', '35723', '39404', '15705', '65139', '50984', '22249', '9264', '34963', '51239', '29072', '15757', '62131', '35679', '49869', '50140', '22721', '24256', '50972', '66518', '23568', '67899', '50198', '35841', '23630', '73272', '52932', '50125', '27426', '5464', '9040', '46885', '86236', '11136', '61363', '46948', '46087', '15648', '35342', '81055.1', '50366', '29410', '27488', '86087', '67972', '28662', '86659', '3453', '79713', '20037', '49333', '7035', '8727', ...
#  'TURSO_AUTH_TOKEN': 'eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3MTQzOTcxNDMsImlkIjoiM2MxZDExZjgtNTE5Yi00Mzg2LWE0ZTMtOTQ4ODBlYWM2YWI4In0.TV1cANsRrUwnV1Wi_sg6dUIq7PZ6kn7a2kKGMmcYI9u0SPM3Tz0G3PdQnGGAgqv6n_4SsEBDb1IWbJec3SCbBA',
#  'DOTENV_SHARED': 'shared.env',
#  'DOTENV_TEMP': 'temp.env',
#  'ITEMS_FOLDER': 'items',
#  'URL_SITEMAP': 'https://tienda.mercadona.es/sitemap.xml',
#  'URL_API': 'https://tienda.mercadona.es/api/v1_1/products',
#  'URL_CATEGORIES': 'https://tienda.mercadona.es/api/categories',
#  'URL_IMAGES': 'https://prod-mercadona.imgix.net/images',
#  'PARAMS_API': "{'lang': 'es', 'wh': 'vlc1'}",
#  'PARAMS_THUMBNAIL': "{'fit': 'crop', 'h': 300, 'w': 300}",
#  'FORMAT_DATE': '%Y%m%d',
#  'TURSO_DATABASE_URL': 'libsql://mercadona-tracker-miguelclaramunt.turso.io',
#  'YMD': "['ymd']",
#  'IDS': "['id', 'ean']",
#  'HASH': "['hash']",
#  'CATEGORIES_JSON': "['categories']",
#  'PRICES': "['iva', 'is_new',  'is_pack', 'pack_size',  'unit_name', 'unit_size',  'bulk_price', 'unit_price',  'approx_size', 'size_format',  'total_units', 'unit_selector',  'bunch_selector', 'drained_weight', 'selling_method', 'price_decreased', 'reference_price', 'min_bunch_amount', 'reference_format', 'previous_unit_price', 'increment_bunch_amount']",
#  'PRODUCTS': "['slug', 'brand', 'is_water', 'requires_age_check', 'origin', 'brand1', 'origin1', 'suppliers', 'legal_name', 'description', 'counter_info', 'danger_mentions', 'alcohol_by_volume', 'mandatory_mentions', 'production_variant', 'usage_instructions', 'storage_instructions', 'is_bulk', 'packaging', 'published', 'thumbnail', 'display_name', 'is_variable_weight', 'allergens', 'ingredients']",
#  'CATEGORIES': "['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name']",
#  'CATEGORIES_FINAL': '["level", "name"]',
#  '_CATEGORIES_JER': "[['l1', 'l1_name', 'ymd'], ['l2', 'l2_name', 'ymd'], ['l3', 'l3_name', 'ymd']]",
#  'COLUMNS_TO_DROP': '["suppliers", "counter_info", "danger_mentions", "alcohol_by_volume", "mandatory_mentions", "production_variant", "usage_instructions", "storage_instructions", "allergens"]',
#  'ITEMS_DTYPES': "{'id': 'string', 'ean': 'int', 'slug': 'string', 'brand': 'string', 'is_water': 'bool', 'requires_age_check': 'bool', 'origin': 'string', 'brand_1': 'string', 'origin_1': 'string', 'suppliers': 'string', 'legal_name': 'string', 'description': 'string', 'counter_info': 'string', 'danger_mentions': 'string', 'alcohol_by_volume': 'string', 'mandatory_mentions': 'string', 'production_variant': 'string', 'usage_instructions': 'string', 'storage_instructions': 'string', 'is_bulk': 'bool', 'packaging': 'string', 'published': 'bool', 'thumbnail': 'string', 'display_name': 'string', 'is_variable_weight': 'bool', 'iva': 'int', 'is_new': 'bool', 'is_pack': 'bool', 'pack_size': 'float64', 'unit_name': 'category', 'unit_size': 'float', 'bulk_price': 'float', 'unit_price': 'float', 'approx_size': 'bool', 'size_format': 'category', 'total_units': 'int', 'unit_selector': 'bool', 'bunch_selector': 'bool', 'drained_weight': 'float64', 'selling_method': 'int', 'price_decreased': 'bool', 'reference_price': 'float', 'min_bunch_amount': 'float64', 'reference_format': 'string', 'previous_unit_price': 'string', 'increment_bunch_amount': 'float64', 'allergens': 'string', 'ingredients': 'string', 'l1': 'int', 'l1_name': 'string', 'l2': 'int', 'l2_name': 'string', 'l3': 'int', 'l3_name': 'string', 'ymd': 'string'}",
#  'COLUMNS_TO_CONCATENATE': '["_ITEMS_COLUMNS", "ITEMS_COLUMNS", "_PRICES_COLUMNS", "PRICES_COLUMNS", "_PRODUCTS_COLUMNS", "PRODUCTS_COLUMNS", "_CATEGORIES_COLUMNS", "CATEGORIES_COLUMNS", "_IDS_CATEGORIES_COLUMNS", "IDS_CATEGORIES_COLUMNS"]',
#  '_ITEMS_COLUMNS': '["IDS", "PRODUCTS", "PRICES", "CATEGORIES_JSON", "CATEGORIES", "YMD"]',
#  'ITEMS_COLUMNS': '["IDS", "PRODUCTS", "PRICES", "CATEGORIES", "YMD"]',
#  '_PRICES_COLUMNS': '["IDS", "PRICES", "YMD"]',
#  'PRICES_COLUMNS': '["IDS", "PRICES", "HASH", "YMD"]',
#  '_PRODUCTS_COLUMNS': '["IDS", "PRODUCTS", "YMD"]',
#  'PRODUCTS_COLUMNS': '["IDS", "PRODUCTS", "HASH", "YMD"]',
#  '_CATEGORIES_COLUMNS': '["CATEGORIES_FINAL", "YMD"]',
#  'CATEGORIES_COLUMNS': '["CATEGORIES_FINAL", "HASH", "YMD"]',
#  '_IDS_CATEGORIES_COLUMNS': '["IDS", "CATEGORIES", "YMD"]',
#  'IDS_CATEGORIES_COLUMNS': '["IDS", "CATEGORIES", "HASH", "YMD"]',
#  'ETL_PARAMETERS': '[{\'table\': \'products\', \'columns_to_select\': \'_PRODUCTS_COLUMNS\', \'columns_to_hash\': "PRODUCTS", \'subset_duplicates\': [\'id\', \'hash\']}, {\'table\': \'ids_categories\', \'columns_to_select\': \'_IDS_CATEGORIES_COLUMNS\', \'columns_to_hash\': "CATEGORIES", \'subset_duplicates\': [\'id\', \'hash\']}, {\'table\': \'categories\', \'columns_to_select\': \'_CATEGORIES_COLUMNS\', \'columns_to_hash\': "CATEGORIES_FINAL", \'subset_duplicates\': [\'hash\']}]'}

# %%
import ast
from dataclasses import dataclass, field
import glob
from itertools import chain
import os
from typing import Dict, List, Tuple, Union

import dotenv


@dataclass
class Config:
    paths: Union[List[str,], Tuple[str,], None] = None
    os: Union[bool, None] = None
    # dict_: dict = field(init=False)

    @classmethod
    def _search(cls, path: str) -> list:
        return glob.glob(pathname=path)

    @classmethod
    def _load_dotenv(cls, paths: List[str,]) -> Dict[str, str | None]:
        return dict(
            chain.from_iterable(
                dotenv.dotenv_values(dotenv_path=path).items() for path in paths
            )
        )

    def __post_init__(self):
        if self.paths is None:
            self.paths = self._search(
                os.path.expanduser("~/git/mercadona-tracker/*.env")
            )
        self.dict_ = self._load_dotenv(self.paths)

    def _refresh(self) -> "Config":
        for variable in self.dict_.keys():
            try:
                self.dict_[variable] = ast.literal_eval(self.dict_[variable])
            except (ValueError, SyntaxError):
                continue

        return self

    def load(self, postprocess: bool = True) -> dict:
        self.dict_ = self._load_dotenv(self.paths)
        self._refresh()

        if postprocess:
            self._concatenate_cols(
                var_name="COLUMNS_TO_CONCATENATE"
            )._generate_etl_parameters(var_name="ETL_PARAMETERS")

        return self.dict_

    ##

    def _concatenate_cols(self, var_name: str = "COLUMNS_TO_CONCATENATE") -> "Config":
        for var in self.dict_[var_name]:
            self.dict_[var] = sum(
                [self.dict_[column] for column in self.dict_[var]], []
            )

        return self

    def _generate_etl_parameters(self, var_name: str = "ETL_PARAMETERS") -> "Config":
        for i, parameters in enumerate(self.dict_[var_name]):
            for column in ("columns_to_select", "columns_to_hash"):
                try:
                    self.dict_[var_name][i][column] = self.dict_[parameters[column]]
                except TypeError:
                    continue


# paths = Config._search()
# Config._load_dotenv(Config._search(os.path.expanduser("~/git/mercadona-tracker/*.env")))
Config().load()
# Out:
# {'LASTMOD_DATE': 20240521,
#  'ALL_IDS': ['63464',
#   '35677',
#   '61250',
#   '34102',
#   '14423',
#   '37276',
#   '22823',
#   '46025',
#   '63592',
#   '44341',
#   '58261',
#   '60345',
#   '27905',
#   '34184',
#   '23372',
#   '22694',
#   '35344',
#   '15260',
#   '35887',
#   '19808',
#   '35643',
#   '7882',
#   '49976',
#   '80784',
#   '4041',
#   '12364',
#   '46434',
#   '26011',
#   '67814',
#   '23047',
#   '16737',
#   '80398',
#   '15794',
#   '17327',
#   '35402',
#   '22453',
#   '46954',
#   '52561',
#   '59336',
#   '52891',
#   '49750',
#   '52884',
#   '23048',
#   '67660',
#   '13576',
#   '27414',
#   '49154',
#   '72537',
#   '63629',
#   '44000',
#   '79260',
#   '79344',
#   '20584',
#   '15967',
#   '4493',
#   '54209',
#   '5005',
#   '83558',
#   '16833',
#   '80515',
#   '50614',
#   '23926',
#   '71527',
#   '28506',
#   '15597',
#   '69099',
#   '5219',
#   '69519',
#   '15936',
#   '28190',
#   '5042',
#   '28187',
#   '35541',
#   '79632',
#   '23646',
#   '20029',
#   '86835',
#   '62503',
#   '63597',
#   '22697',
#   '52426',
#   '52686',
#   '3651',
#   '20991',
#   '67930',
#   '23353',
#   '10354',
#   '73988',
#   '28775',
#   '11427',
#   '26174',
#   '67712',
#   '16830',
#   '78516',
#   '46862',
#   '60846',
#   '38145',
#   '86593',
#   '53041',
#   '63451',
#   '39922',
#   '44982',
#   '26039',
#   '11732',
#   '82732',
#   '23544',
#   '73252',
#   '8295',
#   '80353',
#   '22009',
#   '65324',
#   '82655',
#   '46771',
#   '3236',
#   '10678',
#   '22926',
#   '80267',
#   '40275',
#   '60128',
#   '60127',
#   '46766',
#   '67635',
#   '43088',
#   '87616',
#   '44984',
#   '15985',
#   '53500',
#   '21151',
#   '50916',
#   '34817',
#   '43028',
#   '73002',
#   '3460',
#   '82551',
#   '35633',
#   '69469',
#   '21307',
#   '23037',
#   '22688',
#   '82417',
#   '73195',
#   '4491',
#   '4797',
#   '4798',
#   '20107',
#   '73172',
#   '86749',
#   '35881',
#   '47600',
#   '23413',
#   '46405',
#   '59993',
#   '82609',
#   '63477',
#   '9395',
#   '67967',
#   '76465',
#   '13417',
#   '22007',
#   '58488',
#   '79358',
#   '52533',
#   '86469',
#   '14080',
#   '4912',
#   '63474',
#   '73274',
#   '23702',
#   '22836',
#   '43474',
#   '52877',
#   '15137',
#   '35420',
#   '40277',
#   '10226',
#   '58154',
#   '60719',
#   '8122',
#   '35475',
#   '15628',
#   '76178',
#   '73443',
#   '58286',
#   '52607',
#   '12017',
#   '5396',
#   '86588',
#   '18055',
#   '11307',
#   '84937',
#   '86905',
#   '22631',
#   '28494',
#   '6282',
#   '40259',
#   '63478',
#   '87683',
#   '70756',
#   '62499',
#   '78132',
#   '15922',
#   '82117',
#   '78510',
#   '85786',
#   '34115',
#   '54105',
#   '87607',
#   '34121',
#   '52503',
#   '23410',
#   '34125',
#   '14131',
#   '35983',
#   '44262',
#   '14212',
#   '78975',
#   '28069',
#   '67940',
#   '42384',
#   '9377',
#   '52973',
#   '22281',
#   '40573',
#   '34138',
#   '2851',
#   '17108',
#   '23662',
#   '46877',
#   '11470',
#   '29062',
#   '49619',
#   '24016',
#   '3499',
#   '52560',
#   '35274',
#   '24511',
#   '64087',
#   '50654',
#   '60348',
#   '67949',
#   '23516',
#   '2856',
#   '23019',
#   '63526',
#   '67125',
#   '35545',
#   '35360',
#   '25353',
#   '46834',
#   '23013',
#   '79080',
#   '77241',
#   '82585',
#   '52481',
#   '3291',
#   '23523',
#   '71227',
#   '67534',
#   '44508',
#   '44363',
#   '34236',
#   '16004',
#   '23540',
#   '76596',
#   '47608',
#   '67658',
#   '27571',
#   '63628',
#   '46420',
#   '22932',
#   '40358',
#   '79531',
#   '23643',
#   '18313',
#   '7949',
#   '52553',
#   '35934',
#   '3297',
#   '14159',
#   '33581',
#   '22180',
#   '60790',
#   '50124',
#   '88407',
#   '59343',
#   '44280',
#   '35590',
#   '55130',
#   '73445',
#   '55028',
#   '6245',
#   '37164',
#   '13631',
#   '52850',
#   '46615',
#   '50170',
#   '52852',
#   '63532',
#   '84930',
#   '24032',
#   '51068',
#   '32045',
#   '59254',
#   '24708',
#   '40583',
#   '13598',
#   '52738',
#   '64249',
#   '61248',
#   '11172',
#   '23773',
#   '82302',
#   '60581',
#   '33436',
#   '22280',
#   '13615',
#   '52445',
#   '11770',
#   '60722',
#   '4915',
#   '61027',
#   '8187',
#   '50375',
#   '27491',
#   '7031',
#   '9034',
#   '46953',
#   '86231',
#   '47818',
#   '69166',
#   '83869',
#   '23052',
#   '82938',
#   '50326',
#   '22081',
#   '44289',
#   '63606',
#   '43223',
#   '52669',
#   '47349',
#   '59078',
#   '60623',
#   '70652',
#   '63528',
#   '35540',
#   '35531',
#   '52531',
#   '21358',
#   '87609',
#   '55142',
#   '43482',
#   '79712',
#   '19740',
#   '53032',
#   '46857',
#   '51079',
#   '80782',
#   '15777',
#   '44286',
#   '13388',
#   '7881',
#   '79069',
#   '29019',
#   '38007',
#   '51193',
#   '80707',
#   '14639',
#   '86040',
#   '3561',
#   '46893',
#   '49302',
#   '86288',
#   '15076',
#   '27971',
#   '50459',
#   '35944',
#   '33120',
#   '51167',
#   '50545',
#   '61034',
#   '52941',
#   '22343',
#   '86021',
#   '82277',
#   '86798',
#   '42296',
#   '60015',
#   '22503',
#   '50256',
#   '12531',
#   '52532',
#   '16807',
#   '46768',
#   '50192',
#   '50199',
#   '35723',
#   '39404',
#   '15705',
#   '65139',
#   '50984',
#   '22249',
#   '9264',
#   '34963',
#   '51239',
#   '29072',
#   '15757',
#   '62131',
#   '35679',
#   '49869',
#   '50140',
#   '22721',
#   '24256',
#   '50972',
#   '66518',
#   '23568',
#   '67899',
#   '50198',
#   '35841',
#   '23630',
#   '73272',
#   '52932',
#   '50125',
#   '27426',
#   '5464',
#   '9040',
#   '46885',
#   '86236',
#   '11136',
#   '61363',
#   '46948',
#   '46087',
#   '15648',
#   '35342',
#   '81055.1',
#   '50366',
#   '29410',
#   '27488',
#   '86087',
#   '67972',
#   '28662',
#   '86659',
#   '3453',
#   '79713',
#   '20037',
#   '49333',
#   '7035',
#   '8727',
#   '83789',
#   '61288',
#   '52645',
#   '15810',
#   '16415',
#   '83858.1',
#   '51012',
#   '61053',
#   '61305',
#   '29036',
#   '60347',
#   '86233',
#   '42204',
#   '23172',
#   '68149',
#   '22621',
#   '49049',
#   '4888',
#   '10670',
#   '78595',
#   '20830',
#   '86610.1',
#   '68106',
#   '30138',
#   '86610.2',
#   '11077',
#   '67906',
#   '61368',
#   '35668',
#   '49975',
#   '44914',
#   '35774',
#   '13652',
#   '7980',
#   '51627',
#   '46989',
#   '39403',
#   '58248',
#   '78073',
#   '51641',
#   '80057',
#   '23701',
#   '72614',
#   '52590',
#   '4425',
#   '35661',
#   '84643',
#   '35579',
#   '60659',
#   '46390',
#   '60667',
#   '60688',
#   '60946',
#   '46441',
#   '13568',
#   '23675',
#   '66172',
#   '18037',
#   '29373',
#   '50480',
#   '80253',
#   '79593',
#   '11171',
#   '35749',
#   '35378',
#   '20031',
#   '84654',
#   '8267',
#   '4494',
#   '21756',
#   '51110',
#   '35101',
#   '51149',
#   '86803',
#   '27761',
#   '43315',
#   '69976',
#   '3454',
#   '79678',
#   '40315',
#   '73984',
#   '23798',
#   '65327',
#   '52977',
#   '28246',
#   '79594',
#   '79707',
#   '14085',
#   '71044',
#   '80531',
#   '43853',
#   '22568',
#   '43914',
#   '76542',
#   '52467',
#   '26110',
#   '27230',
#   '82651',
#   '62012',
#   '70024',
#   '23231',
#   '34865',
#   '3547',
#   '4900',
#   '3554',
#   '63114',
#   '50478',
#   '47609',
#   '61302',
#   '60243',
#   '7956',
#   '4110',
#   '13814',
#   '28715',
#   '35714',
#   '22623',
#   '51199',
#   '51230',
#   '2873',
#   '34217',
#   '52937',
#   '9571',
#   '2849',
#   '52929',
#   '34811',
#   '3321',
#   '35733',
#   '23059',
#   '62048',
#   '76637',
#   '15220',
#   '47030',
#   '22799',
#   '22133',
#   '86597',
#   '67981',
#   '81661.2',
#   '86238',
#   '52794',
#   '10543',
#   '31312',
#   '70646',
#   '16313',
#   '87731',
#   '35662',
#   '20940',
#   '14645',
#   '44281',
#   '50985',
#   '35534',
#   '58489',
#   '13431',
#   '86547',
#   '44355',
#   '10380',
#   '23449',
#   '17039',
#   '58278',
#   '69876',
#   '52562',
#   '10542',
#   '60653',
#   '51197',
#   '10546',
#   '4908',
#   '35732',
#   '13430',
#   '69657',
#   '2439',
#   '49711',
#   '60384',
#   '50321',
#   '52108',
#   '35641',
#   '23117',
#   '11187',
#   '46550',
#   '11719',
#   '23406',
#   '16831',
#   '35941',
#   '9581',
#   '29004',
#   '46659',
#   '11872',
#   '90080',
#   '52573',
#   '52183',
#   '12543',
#   '23670',
#   '64012',
#   '82070',
#   '87194',
#   '67144',
#   '76937',
#   '31540',
#   '23404',
#   '2779',
#   '46724',
#   '60251',
#   '82099',
#   '28757',
#   '35654',
#   '86467',
#   '52853',
#   '39109',
#   '87734',
#   '82842',
#   '22279',
#   '13848',
#   '64419',
#   '43320',
#   '23373',
#   '63581',
#   '84710',
#   '68089',
#   '60046',
#   '9356',
#   '66896',
#   '6152',
#   '16317',
#   '39127',
#   '10355',
#   '12540',
#   '5481',
#   '52837',
#   '37229',
#   '80497',
#   '49704',
#   '20476',
#   '15664',
#   '20200',
#   '22780',
#   '82332',
#   '27338',
#   '22191',
#   '47256',
#   '69971',
#   '42318',
#   '52892',
#   '22580',
#   '46418',
#   '64435',
#   '73270',
#   '33440',
#   '59230',
#   '17502',
#   '22612',
#   '84900',
#   '67060',
#   '22008',
#   '86033',
#   '27598',
#   '23596',
#   '2155',
#   '81234.4',
#   '52538',
#   '80980',
#   '35627',
#   '5480',
#   '46020',
#   '64436',
#   '13713',
#   '80862',
#   '74044',
#   '34193',
#   '39129',
#   '35822',
#   '24417',
#   '76504',
#   '46730',
#   '35392',
#   '47310',
#   '21336',
#   '4570',
#   '61354',
#   '27136',
#   '52821',
#   '17132',
#   '59130',
#   '51151',
#   '35777',
#   '15968',
#   '2860',
#   '45913',
#   '86505',
#   '22837',
#   '20859',
#   '63140',
#   '6250',
#   '23337',
#   '16757',
#   '52992',
#   '23359',
#   '80858',
#   '38131',
#   '60631',
#   '12098',
#   '84688',
#   '33357',
#   '44116',
#   '26101',
#   '50971',
#   '33108',
#   '47207',
#   '86276',
#   '35362',
#   '13643',
#   '13849',
#   '82032',
#   '46424',
#   '7880',
#   '43923',
#   '9445',
#   '52527',
#   '5398',
#   '10884',
#   '10826',
#   '60587',
#   '34173',
#   '46871',
#   '12509',
#   '82322',
#   '26114',
#   '12126',
#   '34924',
#   '65311',
#   '23051',
#   '72408',
#   '21333',
#   '82735',
#   '14216',
#   '20942',
#   '52559',
#   '52740',
#   '8394',
#   '10814',
#   '5593',
#   '13875',
#   '60718',
#   '15862',
#   '12099',
#   '19859',
#   '27842',
#   '71399',
#   '14210',
#   '23277',
#   '8548',
#   '35849',
#   '82649',
#   '82905',
#   '23405',
#   '22718',
#   '28491',
#   '21329',
#   '51223',
#   '13422',
#   '8305',
#   '48652',
#   '63643',
#   '78031',
#   '27054',
#   '59332',
#   '5522',
#   '43057',
#   '46444',
#   '20571',
#   '20727',
#   '9491',
#   '73269',
#   '13548',
#   '61025',
#   '16717',
#   '28566',
#   '17173',
#   '55125',
#   '65328',
#   '22770',
#   '26001',
#   '49224',
#   '35639',
#   '23049',
#   '86100',
#   '22651',
#   '4868',
#   '35403',
#   '65298',
#   '80151',
#   '40365',
#   '13636',
#   '34035',
#   '79433',
#   '4918',
#   '52782',
#   '34997',
#   '52795',
#   '52513',
#   '22899',
#   '22967',
#   '63476',
#   '9210',
#   '23365',
#   '35880',
#   '4040',
#   '34182',
#   '34721',
#   '40246',
#   '14161',
#   '84582',
#   '64200',
#   '65299',
#   '84940',
#   '39191',
#   '51191',
#   '34262',
#   '34172',
#   '52588',
#   '9407',
#   '34188',
#   '18252',
#   '34921',
#   '73331',
#   '21331',
#   '22078',
#   '60530',
#   '35770',
#   '27449',
#   '43820',
#   '21319',
#   '9357',
#   '65077',
#   '35266',
#   '35593',
#   '35594',
#   '70745',
#   '72548',
#   '4361',
#   '27972',
#   '28102',
#   '63407',
#   '22302',
#   '80361',
#   '78983',
#   '44019',
#   '35345',
#   '79035',
#   '33026',
#   '43931',
#   '23560',
#   '23890',
#   '60945',
#   '33639',
#   '34868',
#   '72641',
#   '19837',
#   '73979',
#   '10882',
#   '13445',
#   '63159',
#   '5000',
#   '73166',
#   '44283',
#   '69155',
#   '27100',
#   '50994',
#   '20196',
#   '10050',
#   '45711',
#   '3553',
#   '10054',
#   '73196',
#   '10051',
#   '15942',
#   '14010',
#   '60307',
#   '9421',
#   '59138',
#   '84482',
#   '9188',
#   '29074',
#   '9508',
#   '46658',
#   '75306',
#   '35896',
#   '14087',
#   '43058',
#   '66771',
#   '61215',
#   '8194',
#   '29031',
#   '22648',
#   '16671',
#   '46567',
#   '64464',
#   '8196',
#   '85827',
#   '74081',
#   '7014',
#   '23513',
#   '61282',
#   '23561',
#   '23908',
#   '67774',
#   '46436',
#   '35831',
#   '60354',
#   '15923',
#   '29540',
#   '10117',
#   '67797',
#   '72544',
#   '9536',
#   '73268',
#   '27017',
#   '30006',
#   '15966',
#   '82931',
#   '46995',
#   '52796',
#   '82098',
#   '60954',
#   '14637',
#   '27234',
#   '64166',
#   '9054',
#   '43484',
#   '23003',
#   '11101',
#   '35785',
#   '24703',
#   '7026',
#   '67753',
#   '63509',
#   '3028',
#   '73989',
#   '81649.5',
#   '81200.3',
#   '34149',
#   '16005',
#   '21199',
#   '16040',
#   '63582',
#   '17346',
#   '22723',
#   '38130',
#   '62396',
#   '14113',
#   '15953',
#   '84429',
#   '38111',
#   '35838',
#   '24260',
#   '46727',
#   ...],
#  'TURSO_AUTH_TOKEN': 'eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3MTQzOTcxNDMsImlkIjoiM2MxZDExZjgtNTE5Yi00Mzg2LWE0ZTMtOTQ4ODBlYWM2YWI4In0.TV1cANsRrUwnV1Wi_sg6dUIq7PZ6kn7a2kKGMmcYI9u0SPM3Tz0G3PdQnGGAgqv6n_4SsEBDb1IWbJec3SCbBA',
#  'DOTENV_SHARED': 'shared.env',
#  'DOTENV_TEMP': 'temp.env',
#  'ITEMS_FOLDER': 'items',
#  'URL_SITEMAP': 'https://tienda.mercadona.es/sitemap.xml',
#  'URL_API': 'https://tienda.mercadona.es/api/v1_1/products',
#  'URL_CATEGORIES': 'https://tienda.mercadona.es/api/categories',
#  'URL_IMAGES': 'https://prod-mercadona.imgix.net/images',
#  'PARAMS_API': {'lang': 'es', 'wh': 'vlc1'},
#  'PARAMS_THUMBNAIL': {'fit': 'crop', 'h': 300, 'w': 300},
#  'FORMAT_DATE': '%Y%m%d',
#  'TURSO_DATABASE_URL': 'libsql://mercadona-tracker-miguelclaramunt.turso.io',
#  'YMD': ['ymd'],
#  'IDS': ['id', 'ean'],
#  'HASH': ['hash'],
#  'CATEGORIES_JSON': ['categories'],
#  'PRICES': ['iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount'],
#  'PRODUCTS': ['slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients'],
#  'CATEGORIES': ['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name'],
#  'CATEGORIES_FINAL': ['level', 'name'],
#  '_CATEGORIES_JER': [['l1', 'l1_name', 'ymd'],
#   ['l2', 'l2_name', 'ymd'],
#   ['l3', 'l3_name', 'ymd']],
#  'COLUMNS_TO_DROP': ['suppliers',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'allergens'],
#  'ITEMS_DTYPES': {'id': 'string',
#   'ean': 'int',
#   'slug': 'string',
#   'brand': 'string',
#   'is_water': 'bool',
#   'requires_age_check': 'bool',
#   'origin': 'string',
#   'brand_1': 'string',
#   'origin_1': 'string',
#   'suppliers': 'string',
#   'legal_name': 'string',
#   'description': 'string',
#   'counter_info': 'string',
#   'danger_mentions': 'string',
#   'alcohol_by_volume': 'string',
#   'mandatory_mentions': 'string',
#   'production_variant': 'string',
#   'usage_instructions': 'string',
#   'storage_instructions': 'string',
#   'is_bulk': 'bool',
#   'packaging': 'string',
#   'published': 'bool',
#   'thumbnail': 'string',
#   'display_name': 'string',
#   'is_variable_weight': 'bool',
#   'iva': 'int',
#   'is_new': 'bool',
#   'is_pack': 'bool',
#   'pack_size': 'float64',
#   'unit_name': 'category',
#   'unit_size': 'float',
#   'bulk_price': 'float',
#   'unit_price': 'float',
#   'approx_size': 'bool',
#   'size_format': 'category',
#   'total_units': 'int',
#   'unit_selector': 'bool',
#   'bunch_selector': 'bool',
#   'drained_weight': 'float64',
#   'selling_method': 'int',
#   'price_decreased': 'bool',
#   'reference_price': 'float',
#   'min_bunch_amount': 'float64',
#   'reference_format': 'string',
#   'previous_unit_price': 'string',
#   'increment_bunch_amount': 'float64',
#   'allergens': 'string',
#   'ingredients': 'string',
#   'l1': 'int',
#   'l1_name': 'string',
#   'l2': 'int',
#   'l2_name': 'string',
#   'l3': 'int',
#   'l3_name': 'string',
#   'ymd': 'string'},
#  'COLUMNS_TO_CONCATENATE': ['_ITEMS_COLUMNS',
#   'ITEMS_COLUMNS',
#   '_PRICES_COLUMNS',
#   'PRICES_COLUMNS',
#   '_PRODUCTS_COLUMNS',
#   'PRODUCTS_COLUMNS',
#   '_CATEGORIES_COLUMNS',
#   'CATEGORIES_COLUMNS',
#   '_IDS_CATEGORIES_COLUMNS',
#   'IDS_CATEGORIES_COLUMNS'],
#  '_ITEMS_COLUMNS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'categories',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'ymd'],
#  'ITEMS_COLUMNS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'ymd'],
#  '_PRICES_COLUMNS': ['id',
#   'ean',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'ymd'],
#  'PRICES_COLUMNS': ['id',
#   'ean',
#   'iva',
#   'is_new',
#   'is_pack',
#   'pack_size',
#   'unit_name',
#   'unit_size',
#   'bulk_price',
#   'unit_price',
#   'approx_size',
#   'size_format',
#   'total_units',
#   'unit_selector',
#   'bunch_selector',
#   'drained_weight',
#   'selling_method',
#   'price_decreased',
#   'reference_price',
#   'min_bunch_amount',
#   'reference_format',
#   'previous_unit_price',
#   'increment_bunch_amount',
#   'hash',
#   'ymd'],
#  '_PRODUCTS_COLUMNS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'ymd'],
#  'PRODUCTS_COLUMNS': ['id',
#   'ean',
#   'slug',
#   'brand',
#   'is_water',
#   'requires_age_check',
#   'origin',
#   'brand1',
#   'origin1',
#   'suppliers',
#   'legal_name',
#   'description',
#   'counter_info',
#   'danger_mentions',
#   'alcohol_by_volume',
#   'mandatory_mentions',
#   'production_variant',
#   'usage_instructions',
#   'storage_instructions',
#   'is_bulk',
#   'packaging',
#   'published',
#   'thumbnail',
#   'display_name',
#   'is_variable_weight',
#   'allergens',
#   'ingredients',
#   'hash',
#   'ymd'],
#  '_CATEGORIES_COLUMNS': ['level', 'name', 'ymd'],
#  'CATEGORIES_COLUMNS': ['level', 'name', 'hash', 'ymd'],
#  '_IDS_CATEGORIES_COLUMNS': ['id',
#   'ean',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'ymd'],
#  'IDS_CATEGORIES_COLUMNS': ['id',
#   'ean',
#   'l1',
#   'l1_name',
#   'l2',
#   'l2_name',
#   'l3',
#   'l3_name',
#   'hash',
#   'ymd'],
#  'ETL_PARAMETERS': [{'table': 'products',
#    'columns_to_select': ['id',
#     'ean',
#     'slug',
#     'brand',
#     'is_water',
#     'requires_age_check',
#     'origin',
#     'brand1',
#     'origin1',
#     'suppliers',
#     'legal_name',
#     'description',
#     'counter_info',
#     'danger_mentions',
#     'alcohol_by_volume',
#     'mandatory_mentions',
#     'production_variant',
#     'usage_instructions',
#     'storage_instructions',
#     'is_bulk',
#     'packaging',
#     'published',
#     'thumbnail',
#     'display_name',
#     'is_variable_weight',
#     'allergens',
#     'ingredients',
#     'ymd'],
#    'columns_to_hash': ['slug',
#     'brand',
#     'is_water',
#     'requires_age_check',
#     'origin',
#     'brand1',
#     'origin1',
#     'suppliers',
#     'legal_name',
#     'description',
#     'counter_info',
#     'danger_mentions',
#     'alcohol_by_volume',
#     'mandatory_mentions',
#     'production_variant',
#     'usage_instructions',
#     'storage_instructions',
#     'is_bulk',
#     'packaging',
#     'published',
#     'thumbnail',
#     'display_name',
#     'is_variable_weight',
#     'allergens',
#     'ingredients'],
#    'subset_duplicates': ['id', 'hash']},
#   {'table': 'ids_categories',
#    'columns_to_select': ['id',
#     'ean',
#     'l1',
#     'l1_name',
#     'l2',
#     'l2_name',
#     'l3',
#     'l3_name',
#     'ymd'],
#    'columns_to_hash': ['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name'],
#    'subset_duplicates': ['id', 'hash']},
#   {'table': 'categories',
#    'columns_to_select': ['level', 'name', 'ymd'],
#    'columns_to_hash': ['level', 'name'],
#    'subset_duplicates': ['hash']}]}

# %%
Config.search(os.path.expanduser("~/git/mercadona-tracker/*.env"))
# Out:
# ['/home/miguel/git/mercadona-tracker/temp.env',
#  '/home/miguel/git/mercadona-tracker/secret.env',
#  '/home/miguel/git/mercadona-tracker/shared.env']

# %%
from mercatracker import api, globals

config = globals.load_dotenv()

product = api.Product(id='10000', params=config['PARAMS_API'])
response = product.request()
list(product.process_response(response).keys())
# Out:
# ['id',
#  'ean',
#  'slug',
#  'brand',
#  'limit',
#  '_is_water',
#  '_requires_age_check',
#  'origin',
#  'photos',
#  '_brand',
#  '_origin',
#  '_suppliers',
#  '_legal_name',
#  '_description',
#  '_counter_info',
#  '_danger_mentions',
#  '_alcohol_by_volume',
#  '_mandatory_mentions',
#  '_production_variant',
#  '_usage_instructions',
#  '_storage_instructions',
#  'is_bulk',
#  'packaging',
#  'published',
#  'share_url',
#  'thumbnail',
#  'categories',
#  'extra_info',
#  'display_name',
#  'unavailable_from',
#  'is_variable_weight',
#  '_iva',
#  '_is_new',
#  '_is_pack',
#  '_pack_size',
#  '_unit_name',
#  '_unit_size',
#  '_bulk_price',
#  '_unit_price',
#  '_approx_size',
#  '_size_format',
#  '_total_units',
#  '_unit_selector',
#  '_bunch_selector',
#  '_drained_weight',
#  '_selling_method',
#  '_price_decreased',
#  '_reference_price',
#  '_min_bunch_amount',
#  '_reference_format',
#  '_previous_unit_price',
#  '_increment_bunch_amount',
#  'unavailable_weekdays',
#  '_allergens',
#  '_ingredients']

# %%
import pandas as pd
pd.read_csv('./items/20240423.csv').columns
# Out:
# Index(['id', 'ean', 'slug', 'brand', 'is_water', 'requires_age_check',
#        'origin', 'brand.1', 'origin.1', 'suppliers', 'legal_name',
#        'description', 'counter_info', 'danger_mentions', 'alcohol_by_volume',
#        'mandatory_mentions', 'production_variant', 'usage_instructions',
#        'storage_instructions', 'is_bulk', 'packaging', 'published',
#        'thumbnail', 'display_name', 'is_variable_weight', 'allergens',
#        'ingredients', 'iva', 'is_new', 'is_pack', 'pack_size', 'unit_name',
#        'unit_size', 'bulk_price', 'unit_price', 'approx_size', 'size_format',
#        'total_units', 'unit_selector', 'bunch_selector', 'drained_weight',
#        'selling_method', 'price_decreased', 'reference_price',
#        'min_bunch_amount', 'reference_format', 'previous_unit_price',
#        'increment_bunch_amount', 'l1', 'l1_name', 'l2', 'l2_name', 'l3',
#        'l3_name', 'ymd'],
#       dtype='object')

# %%
import re
from mercatracker import processing, api, globals, scraping, etl
from collections.abc import MutableMapping
import pandas as pd

config = globals.load_dotenv()
all_ids = config["ALL_IDS"]
id = all_ids[0]
lastmod = config['LASTMOD']
response = api.call(id)

processing.process(response, lastmod=lastmod, columns=config["_ITEMS_COLUMNS"])

# item = scraping.process_response(response)
# item = response.json()
# item = processing.flatten_dict(item)
# pd.DataFrame([item]).rename(columns={"_brand": "brand1", "_origin": "origin1"}).rename(
#     columns=lambda x: re.sub("^_", "", x)
# )

# if isinstance(item, dict):
#     df = (
#         pd.DataFrame([item])
#         .rename(columns={"_brand": "brand1", "_origin": "origin1"})
#         .rename(columns=lambda x: re.sub("^_", "", x))
#     )
# else:
#     df = (
#         pd.DataFrame(item)
#         .rename(columns={"_brand": "brand1", "_origin": "origin1"})
#         .rename(columns=lambda x: re.sub("^_", "", x))
#     )
# df = df.rename(columns={"_brand": "brand1", "_origin": "origin1"}).rename(
#     columns=lambda x: re.sub("^_", "", x)
# )

# df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 12
#       9 lastmod = config["LASTMOD_DATE"]
#      10 response = api.call(id)
# ---> 12 processing.process(response, lastmod=lastmod, columns=config["_ITEMS_COLUMNS"])
#      13 # item = scraping.process_response(response)
#      14 # item = response.json()
#      15 # item = processing.flatten_dict(item)
#    (...)
#      35
#      36 # df
#
# File c:\Users\migue\Documents\GITHUB\mercadona_tracker\mercatracker\processing.py:223, in process(response, lastmod, columns)
#     219 def process(
#     220     response: requests.Response, lastmod: int, columns=list[str]
#     221 ) -> pd.DataFrame:
#     222     item = scraping.process_response(response)
# --> 223     return items2df(item, lastmod_date=lastmod, columns=columns)
#
# File c:\Users\migue\Documents\GITHUB\mercadona_tracker\mercatracker\processing.py:181, in items2df(items, lastmod_date, columns)
#     177 # df["extra_info"] = df["extra_info"].apply(
#     178 #     lambda x: next(map(str, x)) if not x == None else None
#     179 # )
#     180 if "suppliers" in df.columns and not isinstance(df["suppliers"][0], str):
# --> 181     df["suppliers"] = df["suppliers"].apply(transform_suppliers)
#     183 if "categories" in df.columns:
#     184     df["l1"], df["l1_name"], df["l2"], df["l2_name"], df["l3"], df["l3_name"] = zip(
#     185         *df["categories"].apply(
#     186             transform_categories, args=("categories", 2, ("id", "name"))
#     187         )
#     188     )
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File c:\Users\migue\Documents\GITHUB\mercadona_tracker\mercatracker\processing.py:56, in transform_suppliers(suppliers_list)
#      55 def transform_suppliers(suppliers_list: list) -> str:
# ---> 56     return "\t".join([i["name"] for i in suppliers_list])
#
# TypeError: 'float' object is not iterable

# %%
item
# Out:
# {'id': '63464',
#  'ean': '8480000634641',
#  'slug': 'masa-fresca-quebrada-brisa-hacendado-pack-2',
#  'brand': 'Hacendado',
#  'limit': 999,
#  '_is_water': False,
#  '_requires_age_check': False,
#  'origin': None,
#  'photos': [{'zoom': 'https://prod-mercadona.imgix.net/images/a4204f6b6fdf6ae9d671d993dd94bff8.jpg?fit=crop&h=1600&w=1600',
#    'regular': 'https://prod-mercadona.imgix.net/images/a4204f6b6fdf6ae9d671d993dd94bff8.jpg?fit=crop&h=600&w=600',
#    'thumbnail': 'https://prod-mercadona.imgix.net/images/a4204f6b6fdf6ae9d671d993dd94bff8.jpg?fit=crop&h=300&w=300',
#    'perspective': 2},
#   {'zoom': 'https://prod-mercadona.imgix.net/images/0e2e988a157d558a95e47f6fdff47ff4.jpg?fit=crop&h=1600&w=1600',
#    'regular': 'https://prod-mercadona.imgix.net/images/0e2e988a157d558a95e47f6fdff47ff4.jpg?fit=crop&h=600&w=600',
#    'thumbnail': 'https://prod-mercadona.imgix.net/images/0e2e988a157d558a95e47f6fdff47ff4.jpg?fit=crop&h=300&w=300',
#    'perspective': 9},
#   {'zoom': 'https://prod-mercadona.imgix.net/images/49756cb29f8f6eb76c9fe1dbeb288590.jpg?fit=crop&h=1600&w=1600',
#    'regular': 'https://prod-mercadona.imgix.net/images/49756cb29f8f6eb76c9fe1dbeb288590.jpg?fit=crop&h=600&w=600',
#    'thumbnail': 'https://prod-mercadona.imgix.net/images/49756cb29f8f6eb76c9fe1dbeb288590.jpg?fit=crop&h=300&w=300',
#    'perspective': 4}],
#  '_brand': 'Hacendado',
#  '_origin': None,
#  '_suppliers': [{'name': 'CASA TARRADELLAS, S.A.'}],
#  '_legal_name': 'Masa Quebrada-Brisa',
#  '_description': 'Masa fresca quebrada brisa Hacendado',
#  '_counter_info': None,
#  '_danger_mentions': '',
#  '_alcohol_by_volume': None,
#  '_mandatory_mentions': 'ENVASADO EN ATMÓSFERA PROTECTORA / 2 MASAS REDONDAS / elaborada con el corazón del trigo con harina de nuestro propio molino / MASA CRUDA. CONSUMIR DESPUÉS DE HORNEAR / SIN grasas hidrogenadas / ¡NO SUBE! / CORTAR CON TIJERAS / Teléfono de atención al cliente Mercadona: 800 500 220 / PUNTO VERDE (logo) / RECICLA (logo amarillo y azul) / SUGERENCIA DE PRESENTACIÓN / ABRIR AQUÍ /Evitar que el papel toque las paredes del horno. La temperatura del horno no debe ser superior a 220ºC',
#  '_production_variant': '',
#  '_usage_instructions': '1 - Precalentar el horno a 200ºC.  2 - Sacar la masa de la nevera y mantenerla a temperatura ambiente durante unos minutos. 3. Desenrollar la masa con el papel de cocción y colocarla sobre la bandeja del horno fría o en el molde deseado. 4 - Pinchar con u',
#  '_storage_instructions': 'PUEDE CONGELARSE JUSTO DESPUÉS DE SU COMPRA / MANTÉNGASE ENTRE 0C y 5C / Consumir preferentemente antes del/lote:',
#  'is_bulk': False,
#  'packaging': 'Pack-2',
#  'published': True,
#  'share_url': 'https://tienda.mercadona.es/product/63464/masa-fresca-quebrada-brisa-hacendado-pack-2',
#  'thumbnail': 'https://prod-mercadona.imgix.net/images/a4204f6b6fdf6ae9d671d993dd94bff8.jpg?fit=crop&h=300&w=300',
#  'categories': [{'id': 5,
#    'name': 'Panadería y pastelería',
#    'level': 0,
#    'order': 512,
#    'categories': [{'id': 69,
#      'name': 'Harina y preparado repostería',
#      'level': 1,
#      'order': 512,
#      'categories': [{'id': 338,
#        'name': 'Masas',
#        'level': 2,
#        'order': 512}]}]}],
#  'extra_info': [None],
#  'display_name': 'Masa fresca quebrada brisa Hacendado',
#  'unavailable_from': None,
#  'is_variable_weight': False,
#  '_iva': 10,
#  '_is_new': False,
#  '_is_pack': True,
#  '_pack_size': 0.23,
#  '_unit_name': 'paquetes',
#  '_unit_size': 0.46,
#  '_bulk_price': '5.65',
#  '_unit_price': '2.60',
#  '_approx_size': False,
#  '_size_format': 'kg',
#  '_total_units': 2,
#  '_unit_selector': True,
#  '_bunch_selector': False,
#  '_drained_weight': None,
#  '_selling_method': 0,
#  '_price_decreased': False,
#  '_reference_price': '5.653',
#  '_min_bunch_amount': 1.0,
#  '_reference_format': 'kg',
#  '_previous_unit_price': None,
#  '_increment_bunch_amount': 1.0,
#  'unavailable_weekdays': [],
#  '_allergens': 'Contiene <strong>trigo y productos derivados</strong>. Puede contener <strong>mostaza y productos derivados</strong>. Puede contener <strong>soja y productos a base de soja</strong>. Contiene <strong>cereales que contengan gluten</strong>. Puede contener <strong>leche y sus derivados (incluida la lactosa)</strong>.',
#  '_ingredients': 'Harina de <strong>trigo</strong>, agua, grasas vegetales no hidrogenadas (palma, nabina), sal, zumo de limón concentrado.   Puede contener trazas de derivados <strong>lácteos</strong>, <strong>soja</strong> y <strong>mostaza</strong>.'}

# %%
from mercatracker import scraping
config = globals.load_dotenv()
soup = scraping.get_soup(url=config["URL_SITEMAP"])
all_ids = scraping.search_all(
        scraping.get_tags(soup, tag="loc", skiprows=1), pattern=r"(\d+(?:\.\d+)?)"
    )

# %%
from datetime import date

temporal.updated_ids()
# Out:
# True

# %%
from mercatracker import temporal

temporal.iso_date2custom_format(
    str(date.today()), custom_format=config["FORMAT_DATE"]
) == str(config['LASTMOD'])
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 from mercatracker import datetime
# ----> 2 datetime.iso_date2custom_format(
#       3         str(date.today()), custom_format=config["FORMAT_DATE"]
#       4     ) == str(config["LASTMOD_DATE"])
#
# File c:\Users\migue\Documents\GITHUB\mercadona_tracker\mercatracker\datetime.py:9, in iso_date2custom_format(iso_date, custom_format)
#       8 def iso_date2custom_format(iso_date: str, custom_format: str) -> str:
# ----> 9     date = date.fromisoformat(iso_date)
#      10     return date.strftime(custom_format)
#
# UnboundLocalError: cannot access local variable 'date' where it is not associated with a value

# %%
import datetime
from mercatracker import temporal

temporal.updated_ids()
# Out:
# True

# %%
config['ALL_IDS']
# Out:
# ['63464',
#  '35677',
#  '61250',
#  '34102',
#  '14423',
#  '37276',
#  '22823',
#  '46025',
#  '63592',
#  '44341',
#  '58261',
#  '60345',
#  '27905',
#  '34184',
#  '23372',
#  '34134',
#  '22694',
#  '35344',
#  '15260',
#  '35887',
#  '19808',
#  '35643',
#  '7882',
#  '49976',
#  '80784',
#  '4041',
#  '12364',
#  '46434',
#  '26011',
#  '67814',
#  '23047',
#  '16737',
#  '80398',
#  '15794',
#  '17327',
#  '35402',
#  '22453',
#  '46954',
#  '52561',
#  '59336',
#  '52891',
#  '49750',
#  '52884',
#  '23048',
#  '67660',
#  '27414',
#  '49154',
#  '72537',
#  '63629',
#  '44000',
#  '79260',
#  '79344',
#  '20584',
#  '15967',
#  '4493',
#  '54209',
#  '5005',
#  '83558',
#  '16833',
#  '80515',
#  '50614',
#  '23926',
#  '71527',
#  '28506',
#  '69099',
#  '5219',
#  '69519',
#  '15936',
#  '28190',
#  '83692.5',
#  '5042',
#  '28187',
#  '35541',
#  '79632',
#  '23646',
#  '20029',
#  '86835',
#  '62503',
#  '63597',
#  '22697',
#  '52426',
#  '52686',
#  '3651',
#  '20991',
#  '67930',
#  '23353',
#  '10354',
#  '73988',
#  '28775',
#  '11427',
#  '26174',
#  '67712',
#  '16830',
#  '78516',
#  '46862',
#  '60846',
#  '38145',
#  '86593',
#  '53041',
#  '63451',
#  '39922',
#  '44982',
#  '26039',
#  '11732',
#  '82732',
#  '23544',
#  '73252',
#  '8295',
#  '80353',
#  '22009',
#  '65324',
#  '82655',
#  '46771',
#  '3236',
#  '10678',
#  '22926',
#  '80267',
#  '40275',
#  '60128',
#  '60127',
#  '46766',
#  '67635',
#  '43088',
#  '87616',
#  '44984',
#  '15985',
#  '53500',
#  '21151',
#  '46844',
#  '50916',
#  '34817',
#  '43028',
#  '73002',
#  '3460',
#  '82551',
#  '69469',
#  '21307',
#  '23037',
#  '22688',
#  '82417',
#  '73195',
#  '4491',
#  '4797',
#  '4798',
#  '20107',
#  '73172',
#  '86749',
#  '35881',
#  '47600',
#  '23413',
#  '46405',
#  '59993',
#  '82609',
#  '63477',
#  '9395',
#  '67967',
#  '76465',
#  '13417',
#  '22007',
#  '58488',
#  '79358',
#  '52533',
#  '14080',
#  '4912',
#  '63474',
#  '73274',
#  '23702',
#  '22836',
#  '35632',
#  '43474',
#  '52877',
#  '15137',
#  '35420',
#  '40277',
#  '10226',
#  '58154',
#  '60719',
#  '8122',
#  '35475',
#  '15628',
#  '76178',
#  '73443',
#  '58286',
#  '52607',
#  '12017',
#  '5396',
#  '86588',
#  '18055',
#  '11307',
#  '84937',
#  '86905',
#  '22631',
#  '28494',
#  '6282',
#  '40259',
#  '23617',
#  '63478',
#  '87683',
#  '70756',
#  '62499',
#  '78132',
#  '15922',
#  '82117',
#  '78510',
#  '85786',
#  '34115',
#  '54105',
#  '87607',
#  '34121',
#  '52503',
#  '23410',
#  '34125',
#  '35983',
#  '44262',
#  '14212',
#  '78975',
#  '28069',
#  '67940',
#  '42384',
#  '9377',
#  '52973',
#  '22281',
#  '40573',
#  '34138',
#  '2851',
#  '80292',
#  '17108',
#  '23662',
#  '46877',
#  '11470',
#  '2970',
#  '29062',
#  '49619',
#  '24016',
#  '3499',
#  '52560',
#  '35274',
#  '24511',
#  '64087',
#  '50654',
#  '60348',
#  '67949',
#  '23516',
#  '2856',
#  '23019',
#  '63526',
#  '67125',
#  '35545',
#  '35360',
#  '25353',
#  '46834',
#  '28715',
#  '23013',
#  '79080',
#  '77241',
#  '82585',
#  '52481',
#  '23523',
#  '71227',
#  '67534',
#  '44508',
#  '44363',
#  '34236',
#  '16004',
#  '23540',
#  '76596',
#  '47608',
#  '87692',
#  '27571',
#  '63628',
#  '46420',
#  '22932',
#  '40358',
#  '79531',
#  '23643',
#  '18313',
#  '7949',
#  '52553',
#  '35934',
#  '3297',
#  '14159',
#  '33581',
#  '22180',
#  '60790',
#  '50124',
#  '88407',
#  '59343',
#  '44280',
#  '35590',
#  '55130',
#  '73445',
#  '55028',
#  '6245',
#  '37164',
#  '13631',
#  '52850',
#  '46615',
#  '50170',
#  '52852',
#  '63532',
#  '84930',
#  '24032',
#  '51068',
#  '32045',
#  '59254',
#  '24708',
#  '40583',
#  '13598',
#  '52738',
#  '64249',
#  '61248',
#  '11172',
#  '23773',
#  '82302',
#  '60581',
#  '33436',
#  '22280',
#  '13615',
#  '52445',
#  '11770',
#  '60722',
#  '4915',
#  '61027',
#  '8187',
#  '50375',
#  '27491',
#  '7031',
#  '9034',
#  '46953',
#  '86231',
#  '47818',
#  '69166',
#  '83869',
#  '23052',
#  '82938',
#  '50326',
#  '22081',
#  '44289',
#  '63606',
#  '43223',
#  '52669',
#  '47349',
#  '59078',
#  '60623',
#  '70652',
#  '63528',
#  '35540',
#  '35531',
#  '52531',
#  '21358',
#  '87609',
#  '55142',
#  '43482',
#  '79712',
#  '85795',
#  '19740',
#  '53032',
#  '46857',
#  '51079',
#  '80782',
#  '15777',
#  '44286',
#  '13388',
#  '7881',
#  '15534',
#  '79069',
#  '29019',
#  '38007',
#  '51193',
#  '80707',
#  '46861',
#  '86040',
#  '3561',
#  '46893',
#  '49302',
#  '86288',
#  '15076',
#  '27971',
#  '50459',
#  '35944',
#  '33120',
#  '51167',
#  '50545',
#  '61034',
#  '52941',
#  '22343',
#  '86021',
#  '82277',
#  '86798',
#  '42296',
#  '60015',
#  '22503',
#  '50256',
#  '12531',
#  '52532',
#  '16807',
#  '46768',
#  '50192',
#  '50199',
#  '35723',
#  '39404',
#  '15705',
#  '65139',
#  '50984',
#  '22249',
#  '9264',
#  '34963',
#  '46872',
#  '51239',
#  '29072',
#  '15757',
#  '62131',
#  '35679',
#  '49869',
#  '50140',
#  '22721',
#  '24256',
#  '50972',
#  '66518',
#  '23568',
#  '67899',
#  '50198',
#  '35841',
#  '23630',
#  '73272',
#  '52932',
#  '50125',
#  '5464',
#  '9040',
#  '46885',
#  '86236',
#  '11136',
#  '61363',
#  '46948',
#  '46087',
#  '15648',
#  '35342',
#  '81055.1',
#  '50366',
#  '29410',
#  '27488',
#  '86087',
#  '67972',
#  '28662',
#  '86659',
#  '3453',
#  '79713',
#  '20037',
#  '49333',
#  '7035',
#  '8727',
#  '83789',
#  '61288',
#  '52645',
#  '15810',
#  '16415',
#  '83858.1',
#  '51012',
#  '61053',
#  '61305',
#  '29036',
#  '60347',
#  '13693',
#  '86233',
#  '42204',
#  '23172',
#  '68149',
#  '22621',
#  '49049',
#  '4888',
#  '10670',
#  '78595',
#  '20830',
#  '86610.1',
#  '68106',
#  '30138',
#  '86610.2',
#  '81003',
#  '11077',
#  '67906',
#  '61368',
#  '35668',
#  '49975',
#  '44914',
#  '35774',
#  '81661.2',
#  '13652',
#  '7980',
#  '51627',
#  '46989',
#  '39403',
#  '58248',
#  '78073',
#  '51641',
#  '80057',
#  '23701',
#  '72614',
#  '52590',
#  '4425',
#  '35661',
#  '84643',
#  '35579',
#  '60659',
#  '46390',
#  '60667',
#  '60688',
#  '60946',
#  '46441',
#  '13568',
#  '23675',
#  '66172',
#  '18037',
#  '29373',
#  '50480',
#  '80253',
#  '79593',
#  '11171',
#  '35749',
#  '35378',
#  '20031',
#  '84654',
#  '8267',
#  '4494',
#  '21756',
#  '51110',
#  '35101',
#  '51149',
#  '86803',
#  '27761',
#  '43315',
#  '69976',
#  '3454',
#  '79678',
#  '40315',
#  '73984',
#  '23798',
#  '65327',
#  '52977',
#  '28246',
#  '79594',
#  '79707',
#  '14085',
#  '71044',
#  '80531',
#  '43853',
#  '22568',
#  '43914',
#  '76542',
#  '52467',
#  '26110',
#  '27230',
#  '82651',
#  '62012',
#  '70024',
#  '23231',
#  '34865',
#  '3547',
#  '3554',
#  '63114',
#  '50478',
#  '47609',
#  '61302',
#  '60243',
#  '7956',
#  '4110',
#  '35714',
#  '22623',
#  '51199',
#  '4284',
#  '51230',
#  '2873',
#  '34217',
#  '61206',
#  '52937',
#  '9571',
#  '2849',
#  '52929',
#  '34811',
#  '82610.5',
#  '3321',
#  '86174',
#  '35733',
#  '23059',
#  '62048',
#  '76637',
#  '15220',
#  '47030',
#  '22799',
#  '22133',
#  '86597',
#  '67981',
#  '86238',
#  '52794',
#  '10543',
#  '31312',
#  '70646',
#  '16313',
#  '87731',
#  '35662',
#  '20940',
#  '13429',
#  '14645',
#  '44281',
#  '50985',
#  '35534',
#  '58489',
#  '13431',
#  '86547',
#  '44355',
#  '10380',
#  '23449',
#  '58278',
#  '69876',
#  '52562',
#  '10542',
#  '60653',
#  '51197',
#  '10546',
#  '4908',
#  '35732',
#  '13430',
#  '69657',
#  '2439',
#  '49711',
#  '60384',
#  '50321',
#  '69236',
#  '52108',
#  '35641',
#  '23117',
#  '11187',
#  '46550',
#  '11719',
#  '23406',
#  '16831',
#  '35941',
#  '9581',
#  '29004',
#  '46659',
#  '11872',
#  '90080',
#  '52573',
#  '52183',
#  '12543',
#  '23670',
#  '64012',
#  '82070',
#  '87194',
#  '67144',
#  '76937',
#  '31540',
#  '23404',
#  '2779',
#  '46724',
#  '60251',
#  '21235',
#  '82099',
#  '24135',
#  '28757',
#  '35654',
#  '86467',
#  '52853',
#  '39109',
#  '87734',
#  '82842',
#  '22279',
#  '13848',
#  '64419',
#  '43320',
#  '23373',
#  '63581',
#  '84710',
#  '68089',
#  '9356',
#  '66896',
#  '6152',
#  '16317',
#  '39127',
#  '10355',
#  '12540',
#  '5481',
#  '52837',
#  '37229',
#  '80497',
#  '49704',
#  '20476',
#  '15664',
#  '17039',
#  '10730',
#  '20200',
#  '22780',
#  '82332',
#  '27338',
#  '22191',
#  '47256',
#  '69971',
#  '42318',
#  '52892',
#  '22580',
#  '46418',
#  '64435',
#  '73270',
#  '33440',
#  '59230',
#  '17502',
#  '22612',
#  '84900',
#  '67060',
#  '22008',
#  '86033',
#  '27598',
#  '23596',
#  '2155',
#  '81234.4',
#  '52538',
#  '80980',
#  '35627',
#  '5480',
#  '46020',
#  '64436',
#  '13713',
#  '80862',
#  '74044',
#  '34193',
#  '39129',
#  '35822',
#  '24417',
#  '76504',
#  '46730',
#  '35392',
#  '47310',
#  '21336',
#  '4570',
#  '71154',
#  '61354',
#  '79261',
#  '27136',
#  '52821',
#  '17132',
#  '59130',
#  '51151',
#  '35777',
#  '15968',
#  '2860',
#  '86168',
#  '45913',
#  '86505',
#  '17174',
#  '22837',
#  '20859',
#  '63140',
#  '6250',
#  '23337',
#  '16757',
#  '52992',
#  '23359',
#  '80858',
#  '38131',
#  '60631',
#  '12098',
#  '84688',
#  '33357',
#  '44116',
#  '26101',
#  '50971',
#  '33108',
#  '47207',
#  '86276',
#  '35362',
#  '13643',
#  '13849',
#  '82032',
#  '46424',
#  '7880',
#  '43923',
#  '9445',
#  '52527',
#  '5398',
#  '10884',
#  '10826',
#  '60587',
#  '34173',
#  '46871',
#  '12509',
#  '82322',
#  '26114',
#  '12126',
#  '34924',
#  '65311',
#  '23051',
#  '72408',
#  '21333',
#  '82735',
#  '14216',
#  '20942',
#  '52559',
#  '52740',
#  '8394',
#  '10814',
#  '5593',
#  '13875',
#  '60718',
#  '15862',
#  '12099',
#  '19859',
#  '27842',
#  '71399',
#  '14210',
#  '23277',
#  '8548',
#  '35849',
#  '82649',
#  '82905',
#  '59249',
#  '15565',
#  '23405',
#  '22718',
#  '28491',
#  '21329',
#  '51223',
#  '13422',
#  '26997',
#  '48652',
#  '63643',
#  '78031',
#  '27054',
#  '59332',
#  '86077',
#  '5522',
#  '43057',
#  '46444',
#  '20571',
#  '22164',
#  '20727',
#  '9491',
#  '73269',
#  '13548',
#  '61025',
#  '16717',
#  '28566',
#  '17173',
#  '55125',
#  '65328',
#  '22770',
#  '23618',
#  '26001',
#  '49224',
#  '35639',
#  '23049',
#  '86100',
#  '22651',
#  '4868',
#  '35403',
#  '65298',
#  '80151',
#  '40365',
#  '34035',
#  '79433',
#  '4918',
#  '52782',
#  '34997',
#  '52795',
#  '52513',
#  '22899',
#  '22967',
#  '63476',
#  '9210',
#  '23365',
#  '35880',
#  '4040',
#  '34182',
#  '34721',
#  '40246',
#  '14161',
#  '84582',
#  '64200',
#  '65299',
#  '84940',
#  '39191',
#  '51191',
#  '34262',
#  '34172',
#  '52588',
#  '9407',
#  '34188',
#  '18252',
#  '34921',
#  '73331',
#  '21331',
#  '22078',
#  '60530',
#  '35770',
#  '27449',
#  '43820',
#  '21319',
#  '9357',
#  '65077',
#  '35266',
#  '8257',
#  '35593',
#  '35594',
#  '66746',
#  '70745',
#  '72548',
#  '4361',
#  '27972',
#  '28102',
#  '63407',
#  '22302',
#  '80361',
#  '78983',
#  '44019',
#  '35345',
#  '79035',
#  '33026',
#  '43931',
#  '23560',
#  '2831',
#  '23890',
#  '60945',
#  '33639',
#  '34868',
#  '72641',
#  '19837',
#  '73979',
#  '10882',
#  '13445',
#  '63159',
#  '5000',
#  '73166',
#  '44283',
#  '69155',
#  '27100',
#  '50994',
#  '20196',
#  '10050',
#  '45711',
#  '3553',
#  '10054',
#  '73196',
#  '10051',
#  '15942',
#  '14010',
#  '60307',
#  '9421',
#  '59138',
#  '84482',
#  '9188',
#  '29074',
#  '9508',
#  '46658',
#  '75306',
#  '35896',
#  '14087',
#  '43058',
#  '66771',
#  '61215',
#  '8194',
#  '29031',
#  '22648',
#  '16671',
#  '46567',
#  '64464',
#  '8196',
#  '85827',
#  '74081',
#  '7014',
#  '23513',
#  '61282',
#  '23561',
#  '23908',
#  '67774',
#  '46436',
#  '23912',
#  '35831',
#  '60354',
#  '15923',
#  '69139',
#  '29540',
#  '10117',
#  '67797',
#  '72544',
#  '9536',
#  '73268',
#  '27017',
#  '30006',
#  '15966',
#  '82931',
#  '46995',
#  '52796',
#  '82098',
#  '60954',
#  '14637',
#  '64166',
#  '9054',
#  '43484',
#  '23003',
#  '11101',
#  '35785',
#  '24703',
#  ...]

# %%
from mercatracker import globals

try:
    with open(".env.temp", "x") as file: pass
except FileExistsError:
    globals.update_variable({'LAST_MOD_DATE': '20240514'}, file=".env.temp")

# %%
{'LAST_MOD_DATE': '20240514'}.items()
# Out:
# dict_items([('LAST_MOD_DATE', '20240514')])

# %%
conn = sqlite3.connect("mercadona.db")
pd.read_sql("SELECT * FROM categories", conn)
# Out:
#      level                       name       ymd  \
# 0        5     Panadería y pastelería  20240423
# 1       20  Cuidado facial y corporal  20240423
# 2       17                 Congelados  20240423
# 3       12  Aceite, especias y salsas  20240423
# 4        7        Cereales y galletas  20240423
# ..     ...                        ...       ...
# 620    542                     Bitter  20240423
# 621    757                  Toallitas  20240423
# 622    541                     Tónica  20240423
# 623    661                 Accesorios  20240423
# 624    678                     Brillo  20240507
#
#                                  hash
# 0    ecd6a74dc022e5f0fc2095a86d4dacc3
# 1    9b62fb0b05d2f2ba9e9252589aa98eb8
# 2    afc0c33f7dbf171fcecc6e9ac2ed9f62
# 3    ea6a1b8a592d43f7fcad1765463505e3
# 4    c7a0dd603ea809bceff66ee31731012f
# ..                                ...
# 620  2a712285f78edd28d1158383dca9408f
# 621  31afb1d0f31e855f8fb445a8401b0740
# 622  3f82c211110fbe27c3e908e9cab2d0e4
# 623  ffb5bcd487f5d5f4c5e98a0b7fec3b1a
# 624  a4fee938be79b189856053595978bf1b
#
# [625 rows x 4 columns]

# %%
conn = sqlite3.connect("mercadona.db")
lastmod = etl.get_lastmod_sql(table='categories', col="ymd", conn=conn)
recent_files = etl.get_recent_files("./items/*.csv", lastmod=lastmod)

parameters = config["ETL_PARAMETERS"][2]

etl.update_database(
        table=parameters["table"],
        conn=conn,
        columns_to_select=parameters["columns_to_select"],
        columns_to_hash=parameters["columns_to_hash"],
        subset_duplicates=parameters["subset_duplicates"],)
# Out:
# Empty DataFrame
# Columns: [level, name, ymd, hash]
# Index: []

# %%
level, name, ymd = config["_CATEGORIES_COLUMNS"]
# etl.flatten_levels(pd.read_csv(r'items\20240513.csv'))

# %%
cols_original = config["_CATEGORIES_COLUMNS"],
cols_to_rename = config["_CATEGORIES_JER"],
pd.concat(
        (
            df[col].rename(
                columns={
                    df[col].columns[0]: level,
                    df[col].columns[1]: name,
                    df[col].columns[2]: ymd,
                }
            )
            for col in cols_original
        )
    )
# Out:
# ['level', 'name', 'ymd']

# %%
config["CATEGORIES_COLUMNS"]
# Out:
# ['level', 'name', 'hash', 'ymd']

# %%
(
            df[col].rename(
                columns={
                    df[col].columns[0]: level,
                    df[col].columns[1]: name,
                    df[col].columns[2]: ymd,
                }
            )
            for col in cols_original[0]
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       1 (
#       2             df[col].rename(
#       3                 columns={
#       4                     df[col].columns[0]: level,
#       5                     df[col].columns[1]: name,
#       6                     df[col].columns[2]: ymd,
#       7                 }
#       8             )
# ----> 9             for col in cols_original[0]
#      10         )
#
# NameError: name 'cols_original' is not defined

# %%
config["ETL_PARAMETERS"][-1]
# Out:
# {'table': 'categories',
#  'columns_to_select': ['level', 'name', 'ymd'],
#  'columns_to_hash': ['level', 'name'],
#  'subset_duplicates': ['hash']}

# %%
import pandas as pd
level, name, ymd = config["_CATEGORIES_COLUMNS"]
df = etl.read_multiple(recent_files).dropna(subset=config["CATEGORIES"])
cols_original = config["_CATEGORIES_COLUMNS"],
cols_to_rename = config["_CATEGORIES_JER"],
df[cols_original[0]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 import pandas as pd
#       2 level, name, ymd = config["_CATEGORIES_COLUMNS"]
# ----> 3 df = etl.read_multiple(recent_files).dropna(subset=config["CATEGORIES"])
#       4 cols_original = config["_CATEGORIES_COLUMNS"],
#       5 cols_to_rename = config["_CATEGORIES_JER"],
#
# File c:\Users\migue\Documents\GITHUB\mercadona_tracker\mercatracker\etl.py:53, in read_multiple(paths)
#      52 def read_multiple(paths: list[str]) -> pd.DataFrame:
# ---> 53     return pd.concat((pd.read_csv(file) for file in paths), ignore_index=True)
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File c:\Users\migue\miniconda3\envs\merca\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
df[config["CATEGORIES"]+config['YMD']].columns
# Out:
# Index(['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name', 'ymd'], dtype='object')

# %%
# etl.generate_categories(recent_files)[config["ETL_PARAMETERS"][-1]['columns_to_select']], columns_to_hash=config["ETL_PARAMETERS"][-1]['columns_to_hash']
etl.flatten_levels(etl.read_multiple(recent_files).dropna(subset=config["CATEGORIES"]),
        config["_CATEGORIES_COLUMNS"],
        config["_CATEGORIES_JER_COLUMNS"],
    )
# df = etl.read_multiple(recent_files).dropna(subset=config["CATEGORIES"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # etl.generate_categories(recent_files)[config["ETL_PARAMETERS"][-1]['columns_to_select']], columns_to_hash=config["ETL_PARAMETERS"][-1]['columns_to_hash']
# ----> 2 etl.flatten_levels(etl.read_multiple(recent_files).dropna(subset=config["CATEGORIES"]),
#       3         config["_CATEGORIES_COLUMNS"],
#       4         config["_CATEGORIES_JER_COLUMNS"],
#       5     )
#       6 # df = etl.read_multiple(recent_files).dropna(subset=config["CATEGORIES"])
#
# NameError: name 'recent_files' is not defined

# %%
conn = sqlite3.connect("mercadona.db")
df_current, df_updated = etl.update_database(
        table=parameters["table"],
        conn=conn,
        columns_to_select=parameters["columns_to_select"],
        columns_to_hash=parameters["columns_to_hash"],
        subset_duplicates=parameters["subset_duplicates"],
    )

# %%
df_updated[~df_updated.hash.isin(df_current.hash)]
# Out:
# Empty DataFrame
# Columns: [id, ean, l1, l1_name, l2, l2_name, l3, l3_name, ymd, hash]
# Index: []

# %%
for i, parameters in enumerate(config["ETL_PARAMETERS"]):
    for column in ('columns_to_select', 'columns_to_hash'):
        try:
            config["ETL_PARAMETERS"][i][column] = config[parameters[column]]
        except TypeError:
            continue


# list(enumerate(config["ETL_PARAMETERS"][0]['columns_to_hash']))

# config[parameters['columns_to_hash']]
# config[config["ETL_PARAMETERS"][0]['columns_to_select']]

# %%
# for column in ('columns_to_select', 'columns_to_hash'):
#     print(column)

config["ETL_PARAMETERS"]
# Out:
# [{'table': 'products',
#   'columns_to_select': ['id',
#    'ean',
#    'slug',
#    'brand',
#    'badges.is_water',
#    'badges.requires_age_check',
#    'origin',
#    'details.brand',
#    'details.origin',
#    'details.suppliers',
#    'details.legal_name',
#    'details.description',
#    'details.counter_info',
#    'details.danger_mentions',
#    'details.alcohol_by_volume',
#    'details.mandatory_mentions',
#    'details.production_variant',
#    'details.usage_instructions',
#    'details.storage_instructions',
#    'is_bulk',
#    'packaging',
#    'published',
#    'thumbnail',
#    'display_name',
#    'is_variable_weight',
#    'nutrition_information.allergens',
#    'nutrition_information.ingredients',
#    'ymd'],
#   'columns_to_hash': ['slug',
#    'brand',
#    'badges.is_water',
#    'badges.requires_age_check',
#    'origin',
#    'details.brand',
#    'details.origin',
#    'details.suppliers',
#    'details.legal_name',
#    'details.description',
#    'details.counter_info',
#    'details.danger_mentions',
#    'details.alcohol_by_volume',
#    'details.mandatory_mentions',
#    'details.production_variant',
#    'details.usage_instructions',
#    'details.storage_instructions',
#    'is_bulk',
#    'packaging',
#    'published',
#    'thumbnail',
#    'display_name',
#    'is_variable_weight',
#    'nutrition_information.allergens',
#    'nutrition_information.ingredients'],
#   'subset_duplicates': ['id', 'hash']},
#  {'table': 'ids_categories',
#   'columns_to_select': ['id',
#    'ean',
#    'l1',
#    'l1_name',
#    'l2',
#    'l2_name',
#    'l3',
#    'l3_name',
#    'ymd'],
#   'columns_to_hash': ['l1', 'l1_name', 'l2', 'l2_name', 'l3', 'l3_name'],
#   'subset_duplicates': ['id', 'hash']},
#  {'table': 'categories',
#   'columns_to_select': ['level', 'name', 'ymd'],
#   'columns_to_hash': ['level', 'name'],
#   'subset_duplicates': ['hash']}]

# %%
config[parameters['columns_to_hash']]
# Out:
# ['slug',
#  'brand',
#  'badges.is_water',
#  'badges.requires_age_check',
#  'origin',
#  'details.brand',
#  'details.origin',
#  'details.suppliers',
#  'details.legal_name',
#  'details.description',
#  'details.counter_info',
#  'details.danger_mentions',
#  'details.alcohol_by_volume',
#  'details.mandatory_mentions',
#  'details.production_variant',
#  'details.usage_instructions',
#  'details.storage_instructions',
#  'is_bulk',
#  'packaging',
#  'published',
#  'thumbnail',
#  'display_name',
#  'is_variable_weight',
#  'nutrition_information.allergens',
#  'nutrition_information.ingredients']

# %%
config["ETL_PARAMETERS"][0]['columns_to_select'] = config[config["ETL_PARAMETERS"][0]['columns_to_select']]

# %%
config[config["ETL_PARAMETERS"][0]['columns_to_select']]
# Out:
# ['id',
#  'ean',
#  'slug',
#  'brand',
#  'badges.is_water',
#  'badges.requires_age_check',
#  'origin',
#  'details.brand',
#  'details.origin',
#  'details.suppliers',
#  'details.legal_name',
#  'details.description',
#  'details.counter_info',
#  'details.danger_mentions',
#  'details.alcohol_by_volume',
#  'details.mandatory_mentions',
#  'details.production_variant',
#  'details.usage_instructions',
#  'details.storage_instructions',
#  'is_bulk',
#  'packaging',
#  'published',
#  'thumbnail',
#  'display_name',
#  'is_variable_weight',
#  'nutrition_information.allergens',
#  'nutrition_information.ingredients',
#  'ymd']

# %%
parameters_list[0]['columns_to_select'] = config[para]
# Out:
# {'table': 'products',
#  'columns_to_select': '_PRODUCTS_COLUMNS',
#  'columns_to_hash': 'PRODUCTS',
#  'subset_duplicates': ['id', 'hash']}

# %%
config[column], config[parameters[column]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 config[column], config[parameters[column]]
#
# KeyError: 'columns_to_hash'

# %%
config[parameters[column]]
# Out:
# ['level', 'name']
